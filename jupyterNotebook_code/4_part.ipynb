# %% [markdown]
# #### Import dependencies:

# %%
import sys #access to system parameters https://docs.python.org/3/library/sys.html
print("Python version: {}". format(sys.version))

import pandas as pd #collection of functions for data processing and analysis modeled after R dataframes with SQL like features
print("pandas version: {}". format(pd.__version__))

import matplotlib #collection of functions for scientific and publication-ready visualization
import matplotlib as plt
print("matplotlib version: {}". format(matplotlib.__version__))

import numpy as np #foundational package for scientific computing
print("NumPy version: {}". format(np.__version__))

import scipy as sp #collection of functions for scientific computing and advance mathematics
print("SciPy version: {}". format(sp.__version__)) 

import IPython
from IPython import display #pretty printing of dataframes in Jupyter notebook
print("IPython version: {}". format(IPython.__version__)) 

import sklearn #collection of machine learning algorithms
print("scikit-learn version: {}". format(sklearn.__version__))

#misc libraries
import random
import time
#ignore warnings
import warnings
warnings.filterwarnings('ignore')
print('-'*25)
import re
import os
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Python version: 3.8.5 (default, Sep  4 2020, 02:22:02)
# [Clang 10.0.0 ]
# pandas version: 1.1.3
# matplotlib version: 3.3.2
# NumPy version: 1.19.5
# SciPy version: 1.5.2
# IPython version: 7.19.0
# scikit-learn version: 0.23.2
# -------------------------

# %% [markdown]
# #### Download data file if it has not been downloaded already:

# %%
#url = 'https://data.cityofnewyork.us/api/views/qgea-i56i/rows.csv?accessType=DOWNLOAD'
fn_src = 'https://data.cityofnewyork.us/api/views/sv2w-rv3k/rows.csv?accessType=DOWNLOAD'
fn_dst = 'NYPD-Criminal-Court-Summons-Historic.csv'

from six.moves import urllib

if os.path.isfile(fn_dst):
    print('File %s has already been downloaded' % fn_dst)
else:
    print('Fetching file %s[2.4GB]. This may take a while...' % fn_dst)
    urllib.request.urlretrieve(fn_src, fn_dst)
    print('File %s has been downloaded' % fn_dst)
# Out:
# File NYPD-Criminal-Court-Summons-Historic.csv has already been downloaded

# %% [markdown]
# #### Open a stream to the data file so we don't have to load the whole data set into main memory

# %%
from openclean.pipeline import stream
ds_full = stream(fn_dst)

# %%
print(f'The dataset contains {ds_full.count():,} rows.')
# Out:
# The dataset contains 5,336,264 rows.

# %%
ds_full.head()
# Out:
#   SUMMONS_KEY SUMMONS_DATE       OFFENSE_DESCRIPTION LAW_SECTION_NUMBER  \
# 0   192724412   01/24/2019         UNINSURED VEHICLE                319
# 1   193633599   02/15/2019                 OTHER VTL               9999
# 2   194790153   03/17/2019  MAKES UNREASONABLE NOISE          240.20(2)
# 3   198874018   06/24/2019       OTHER SANITARY CODE               9999
# 4   191809027   01/02/2019  MARIJUANA, POSSESSION OF             221.05
# 5   189573397   10/29/2018         RATES OF PEDICABS             20-260
# 6   188834473   10/16/2018         OTHER TRAFFIC REG               9999
# 7   192166453   01/11/2019                 EQUIPMENT                375
# 8   187391089   09/09/2018         PERMIT UNLICENSED          19-506(B)
# 9   189477530   11/01/2018          RECKLESS DRIVING               1212
#
#   LAW_DESCRIPTION SUMMONS_CATEGORY_TYPE AGE_GROUP SEX            RACE  \
# 0             VTL                   VTL   UNKNOWN
# 1             VTL                   VTL   UNKNOWN
# 2                                           25-44   M  WHITE HISPANIC
# 3             ABC             OTHER ABC   UNKNOWN
# 4       Penal Law             MARIJUANA     25-44   M           BLACK
# 5                                           25-44   M           WHITE
# 6             ABC             OTHER ABC   UNKNOWN
# 7             VTL                   VTL   UNKNOWN
# 8                                         UNKNOWN
# 9             VTL                   VTL     45-64   M           BLACK
#
#   JURISDICTION_CODE      BORO PRECINCT_OF_OCCUR X_COORDINATE_CD  \
# 0                 0  NEW YORK                18          990060
# 1                 0  BROOKLYN                78          991048
# 2                 0  BROOKLYN                72          984058
# 3                 0    QUEENS               109         1031014
# 4                 0     BRONX                44         1003989
# 5                 0  NEW YORK                14          986072
# 6                 0  BROOKLYN                63         1005474
# 7                 0  NEW YORK                 1          982611
# 8                 0    QUEENS               103         1040896
# 9                 2  BROOKLYN                77         1003508
#
#   Y_COORDINATE_CD            Latitude            Longitude  \
# 0          217404  40.763406514000053  -73.979028011999958
# 1          187513  40.681362236000041  -73.975491630999954
# 2          178998  40.657993066000074  -74.000693445999957
# 3          217293  40.762980083000059  -73.831189714999937
# 4          244111  40.836689797000076  -73.928667417999975
# 5          212412         40.74970647         -73.99342559
# 6          161744         40.61060908         -73.92356057
# 7          202413  40.722261709000065  -74.005914397999959
# 8          196247         40.70515635         -73.79569434
# 9          185056         40.67459999         -73.93057482
#
#                                          Lon_Lat
# 0   POINT (-73.97902801199996 40.76340651400006)
# 1   POINT (-73.97549163099997 40.68136223600004)
# 2  POINT (-74.00069344599996 40.657993066000074)
# 3   POINT (-73.83118971499994 40.76298008300006)
# 4  POINT (-73.92866741799997 40.836689797000076)
# 5               POINT (-73.99342559 40.74970647)
# 6               POINT (-73.92356057 40.61060908)
# 7  POINT (-74.00591439799996 40.722261709000065)
# 8               POINT (-73.79569434 40.70515635)
# 9               POINT (-73.93057482 40.67459999)

# %% [markdown]
# #### Use openclean to profile the data set:

# %%
from openclean.profiling.column import DefaultColumnProfiler

#profiles = ds.profile(default_profiler=DefaultColumnProfiler)
profiles = ds_full.profile(default_profiler=DefaultColumnProfiler)

# %%
profiles.stats()
# Out:
#                          total   empty  distinct    uniqueness    entropy
# SUMMONS_KEY            5336264       0   5336248  9.999970e-01  22.347392
# SUMMONS_DATE           5336264       0      5479  1.026748e-03  12.132267
# OFFENSE_DESCRIPTION    5336264    1833     18941  3.550707e-03   5.223593
# LAW_SECTION_NUMBER     5336264   76877      6201  1.179035e-03   5.001091
# LAW_DESCRIPTION        5336264   92140        27  5.148620e-06   2.213753
# SUMMONS_CATEGORY_TYPE  5336264   97655        94  1.794369e-05   3.887649
# AGE_GROUP              5336264   83920       222  4.226684e-05   1.885182
# SEX                    5336264   76814         4  7.605358e-07   0.755284
# RACE                   5336264  396655         9  1.822007e-06   0.568514
# JURISDICTION_CODE      5336264       0         3  5.621911e-07   0.553216
# BORO                   5336264  564609         6  1.257425e-06   2.179537
# PRECINCT_OF_OCCUR      5336264       0        81  1.517916e-05   6.070633
# X_COORDINATE_CD        5336264     294     55640  1.042734e-02  13.294972
# Y_COORDINATE_CD        5336264     294     58985  1.105422e-02  13.408931
# Latitude               5336264     294    119434  2.238281e-02  13.826578
# Longitude              5336264     294    122568  2.297014e-02  13.839528
# Lon_Lat                5336264     294    115595  2.166335e-02  13.809289

# %%
# Print the most frequent data type for each column.

print('Schema\n------')
for col in ds_full.columns:
    p = profiles.column(col)
    print("  '{}' ({})".format(col, p['datatypes']['distinct'].most_common(1)[0][0]))
# Out:
# Schema
# ------
#   'SUMMONS_KEY' (int)
#   'SUMMONS_DATE' (date)
#   'OFFENSE_DESCRIPTION' (str)
#   'LAW_SECTION_NUMBER' (str)
#   'LAW_DESCRIPTION' (str)
#   'SUMMONS_CATEGORY_TYPE' (str)
#   'AGE_GROUP' (int)
#   'SEX' (str)
#   'RACE' (str)
#   'JURISDICTION_CODE' (int)
#   'BORO' (str)
#   'PRECINCT_OF_OCCUR' (int)
#   'X_COORDINATE_CD' (int)
#   'Y_COORDINATE_CD' (int)
#   'Latitude' (float)
#   'Longitude' (float)
#   'Lon_Lat' (str)

# %% [markdown]
# ### Field Name & Description:
#     'CMPLNT_NUM' (int)                 Complaint Number
#     'CMPLNT_FR_DT' (date)              Complaint From Date
#     'CMPLNT_FR_TM' (date)              Complaint From Time
#     'CMPLNT_TO_DT' (date)              Complaint To Date
#     'CMPLNT_TO_TM' (date)              Complaint To Time
#     'ADDR_PCT_CD' (int)                Code of Precinct in which the Incident Occured
#     'RPT_DT' (date)                    Report Date
#     'KY_CD' (int)                      "Key Code": Offense Classification Code (3 digits)
#     'OFNS_DESC' (str)                  Offense Description
#     'PD_CD' (int)                      PD Code of Offense. More granular than Key Code
#     'PD_DESC' (str)                    PD Description of Offense.
#     'CRM_ATPT_CPTD_CD' (str)           Whether Crime was Atempted or Completed (values: 'COMPLETED', 'ATTEMPTED')
#     'LAW_CAT_CD' (str)                 Level of Offense (values: 'FELONY', 'VIOLATION', 'MISDEMEANOR')
#     'BORO_NM' (str)                    Name of Borough in which Incident Occurred
#     'LOC_OF_OCCUR_DESC' (str)          Description of where the incident occurred with respect to the premises
#                                        (values:'FRONT OF', 'REAR OF', 'OUTSIDE', 'INSIDE', 'OPPOSITE OF')
#     'PREM_TYP_DESC' (str)              Description of the type of premises in which the Incident Occurred
#     'JURIS_DESC' (str)                 Description of Jurisdiction in which Incident Occurred
#     'JURISDICTION_CODE' (int)          Jurisdiction Code
#     'PARKS_NM' (str)                   Name of Park in which Incident Occurred, if Applicable
#     'HADEVELOPT' (str)                 Name of NYCHA Housing Development in which Incident Occurred, if Applicable
#     'HOUSING_PSA' (int)                Housing PSA
#     'X_COORD_CD' (int)                 X-coordinate, New York State Plane Coordinate System
#     'Y_COORD_CD' (int)                 Y-coordinate, New York State Plane Coordinate System
#     'SUSP_AGE_GROUP' (int)             Age Group of Suspect
#     'SUSP_RACE' (str)                  Race of Suspect
#     'SUSP_SEX' (str)                   Sex of Suspect
#     'TRANSIT_DISTRICT' (int)           Transit-District code
#     'Latitude' (float)                 Global Latitude of Location where Incident Occurred
#     'Longitude' (float)                Global Longitude of Location where Incident Occured
#     'Lat_Lon' (str)                    'Latitude' and 'Longitude' together
#     'PATROL_BORO' (str)                Patrol Borough
#     'STATION_NAME' (str)               Station Name
#     'VIC_AGE_GROUP' (int)              Age Group of Victim
#     'VIC_RACE' (str)                   Race of Victim
#     'VIC_SEX' (str)                    Sex of Victim
#
#
#     (Note: some field descriptions were taken from https://www1.nyc.gov/assets/nypd/downloads/pdf/analysis_and_planning/incident_level_data_footnotes.pdf)

# %% [markdown]
# ## Profiling & Cleaning of each field in the data set

# %%
profiles.minmax('SUMMONS_KEY')
# Out:
#          min        max
# int  5542337  222637918

# %% [raw]
# All summons keys are distinct and no values are empty.Hence, no further cleaning is required.

# %%
profiles.minmax('SUMMONS_DATE')
# Out:
#             min        max
# date 2006-01-01 2020-12-31

# %%
from datetime import datetime
#datetime.strptime('2014-12-04', '%Y-%m-%d').date()


def validate_date(sourceValue):
    dummy_date = datetime.strptime("01/01/1000", '%m/%d/%Y').date()
    
    try:
        source_date = sourceValue
        start_date = datetime.strptime("01/01/2006", '%m/%d/%Y').date()
        end_date = datetime.strptime("12/31/2020", '%m/%d/%Y').date()
    
        if source_date == '':
            source_date = dummy_date
        
        source_date = datetime.strptime(sourceValue, '%m/%d/%Y').date()
        
        if source_date >= start_date and source_date <= end_date:
            return source_date
        else:
            return dummy_date
    except:
        return dummy_date
    

ds_full = ds_full.update('SUMMONS_DATE', validate_date)

# %%
profiles.minmax('PRECINCT_OF_OCCUR')
# Out:
#      min  max
# int    1  868

# %%
profiles.column('PRECINCT_OF_OCCUR').get('topValues')
# Out:
# [('40', 190864),
#  ('75', 189021),
#  ('73', 145704),
#  ('79', 145004),
#  ('115', 144382),
#  ('90', 121689),
#  ('52', 121206),
#  ('44', 120065),
#  ('14', 117273),
#  ('34', 117101)]

# %%
profiles.minmax('LAW_SECTION_NUMBER')
# Out:
#                        min                  max
# int                 -20461             62320465
# str                      *             tax stam
# float                 1.03             4.04e+07
# date   0104-02-11 00:00:00  4012-11-11 00:00:00

# %%
profiles.column('LAW_SECTION_NUMBER').get('topValues')
# Out:
# [('10-125', 1397991),
#  ('9999', 441493),
#  ('1-03', 233137),
#  ('19-176', 214188),
#  ('240.205A', 208198),
#  ('221.05', 190464),
#  ('140.05', 158032),
#  ('CFR 49', 154846),
#  ('153.09', 151386),
#  ('240.20', 148692)]

# %%
profiles.column('OFFENSE_DESCRIPTION').get('topValues')
# Out:
# [('CONSUMPTION OF ALCOHOL', 1402056),
#  ('URINATING IN PUBLIC', 294351),
#  ('FAILURE TO COMPLY WITH SIGN', 259395),
#  ('BICYCLE ON SIDEWALK', 219527),
#  ('DISCON: OBSTRUCT PEDESTRIAN', 210327),
#  ('DISORDERLY CONDUCT', 199382),
#  ('OTHER ADMIN CODE', 187287),
#  ('FEDERAL MOTOR VEH. SAFETY REG', 172954),
#  ('MARIJUANA, POSSESSION OF', 167053),
#  ('TRESPASS', 158354)]

# %%
ds_full.distinct('OFFENSE_DESCRIPTION')
# Out:
# Counter({'UNINSURED VEHICLE': 8249,
#          'OTHER VTL': 43454,
#          'MAKES UNREASONABLE NOISE': 985,
#          'OTHER SANITARY CODE': 582,
#          'MARIJUANA, POSSESSION OF': 167053,
#          'RATES OF PEDICABS': 38,
#          'OTHER TRAFFIC REG': 17740,
#          'EQUIPMENT': 7084,
#          'PERMIT UNLICENSED': 414,
#          'RECKLESS DRIVING': 130913,
#          'DISCON: OBSCENE LANGUAGE/GESTURE': 32339,
#          'UNREGISTERED VEHICLE': 12198,
#          'TRESPASS': 158354,
#          'SALE TO A MINOR': 56,
#          'IMPROPER ENTRANCE/EXIT': 722,
#          'OTHER ABC': 26291,
#          'HIGHWAY USE TAX (NYS)': 4177,
#          'PUBLIC URINATION': 1926,
#          'DEFECTIVE REFLECTOR': 290,
#          'DISORDERLY PREMISE': 5291,
#          'SMOKING IN TRAIN STATION': 2804,
#          'OTHER TRANSIT REG': 4613,
#          'REVOKED REGISTRATION': 12050,
#          'OVERWEIGHT (VEH)': 999,
#          'IMPROPER PLATES': 1554,
#          'NON PAYMENT OF FARE (BUS)': 5255,
#          'NON PAYMENT OF FARE (OTHER)': 6354,
#          'FOR GAMBLING': 533,
#          'IMPROPER STICKER': 2138,
#          'PICK UP FROM BUS STOP': 3606,
#          'CRUELTY TO ANIMAL(S)': 92,
#          'NO TAX STAMP': 27165,
#          'DISORDERLY CONDUCT': 199382,
#          'JAYWALKING': 8704,
#          'SPITTING': 204,
#          'DOG: UNLEASHED': 29496,
#          'OTHER HEALTH CODE': 15706,
#          'OBSTRUCTS VEHICULAR OR PEDESTRIAN TRAFFIC': 4353,
#          'FIRE (WITHOUT PERMIT)': 21,
#          'DISOBEY ANY PARK SIGN': 238,
#          'ACCEPT ON HAIL': 50640,
#          'FAIL TO CHECK ID': 388,
#          'LITTERNG': 2432,
#          'POSS. OF KNIFE': 9014,
#          'NO JUNCTION BOX COVERS': 63,
#          'BICYCLE ON SIDEWALK': 219527,
#          'ALCOHOL IN THE PARK': 128,
#          'AGG. UNLICENSED OPER.': 4856,
#          'OTHER BUSINESS LAW': 1715,
#          'REQUIRED EQUIPMENT OF PEDICABS': 307,
#          'ALCOHOLIC BEVERAGE IN PUBLIC': 7223,
#          'DISORDERLY BEHAVIOR': 170,
#          'OBSTRUCTED VIEW OF PREMISE': 3181,
#          'RECKLESS OPERATION OF A BICYCLE *( C SUMMONS)*': 373,
#          'FEDERAL MOTOR VEH. SAFETY REG': 172954,
#          'RESTRICTIONS ON THE OPERATION OF PEDICABS': 737,
#          'SOLICITING AT SCENE; UNREASONABLE/UNNECESSARY': 32,
#          'POSSESSION OF AN IMITATION PISTOL (TOY) THAT LOOKS REAL': 61,
#          'ENGAGES IN FIGHTING, OR VIOLENT, TUMULTUOUS OR THREATENING BEHAVIOR': 4396,
#          'EVICTION; UNLAWFUL (INTERRUPT ESSENTIAL SERVICES)': 77,
#          'IMPROPERLY OR UNMARKED BEER TAP': 9,
#          'OPERATION WHILE REGISTRATION OR PRIVILEGE IS SUSPENDED OR REVOKED': 6087,
#          'LICENSE, OPERATE WITH SUSPENDED/REVOKED/NONE': 1787,
#          'DISPLAY OF PEDICAB DRIVER?S IDENTIFICATION': 442,
#          'MOTOR VEHICLE; ENGINE ON/KEY IN IGNITION (THERE IS NO TIME REQUIREMENT)': 5320,
#          'BUSINESS NAME NOT DISPLAYED ON THE OUTSIDE': 11,
#          'DISCON: REFUSE LAWFUL ORDER': 67854,
#          'OTHER NYS TRANSPORTATION': 54306,
#          'CREATES A HAZARDOUS OR PHYSICALLY OFFENSIVE CONDITION WITHOUT A LEGITIMATE PURPO': 1542,
#          'WAREHOUSING ALCOHOL WITHOUT A PERMIT': 110,
#          'DEFECTIVE HEADLIGHT': 711,
#          'UNLICENSED VEHICLE FOR HIRE': 59295,
#          'PEDICAB WITHOUT EXTIOR SIGN OF RATES': 376,
#          'CONSUMPTION OF ALCOHOL': 1402056,
#          'FAILURE TO COMPLY WITH SIGN': 259395,
#          'LIQUOR LICENSE NOT POSTED IN A CONSPICUOUS PLACE': 156,
#          'UNINSPECTED VEHICLE': 1740,
#          'SALE TO AN INTOXICATED PERSON': 164,
#          'PEDICAB DRIVER LICENSE': 207,
#          'OTHER ADMIN CODE': 187287,
#          'DISCON: OBSTRUCT VEHICLE': 91816,
#          'FIREWORKS, POSSESS/USE': 5717,
#          'VENDOR: FAIL TO DISPLAY PERMIT': 9016,
#          'OTHER TAX LAW': 4157,
#          'OPERATE WITHOUT BATTERY OPERATED HEADLIGHTS': 328,
#          'OVER CROWDED BAR': 81,
#          'KNIFE, ANY IN PUBLIC VIEW': 20217,
#          'KNIVES; PUBLIC POSSESSION (BLADE 4 INCHES OR MORE)': 473,
#          'MARIJUANA, UNLAWFUL POSSESSION 2ND DEGREE': 14708,
#          'AFTER HOURS CONSUMPTION': 2822,
#          'EVICTION; UNLAWFUL (REMOVE PROPERTY/REMOVE DOOR/CHANGE OR DAMAGE LOCKS)': 137,
#          'AIR PISTOL/RIFLE; SELL OR POSSESS': 80,
#          'EXPOSURE OF PERSON': 8575,
#          'FAIL TO COMPLY WITH TLC REGULATIONS': 24854,
#          'KEY IN IGNITION': 20940,
#          'COMMERCIAL VEHICLE; NAME/ADDRESS NOT DISPLAYED': 1840,
#          'NO "BOOK OF DAILY ACTIVITIES"': 242,
#          'CONGREGATES WITH OTHER PERSONS IN PUBLIC AND REFUSES TO DISPERSE BY LAWFUL POLIC': 1965,
#          'OPEN FIRE': 2701,
#          'IDLING OF VEHICLE': 10676,
#          'BOX CUTTER': 5879,
#          'EMPLOY BOUNCER (SECURITY GUARD) WITHOUT VALID REGISTRATION CARD': 224,
#          'PANHANDLING WITHIN 10 FT. OF BANK/ATM/CHECK CASHING BUSINESS': 85,
#          'FAIL TO DISPLAY LICENSE': 187,
#          'BICYCLE INFRACTION (COMMERCIAL)': 35918,
#          'SALE TO A MINOR (UNDER 21)': 394,
#          'FAIL TO MAINTAIN FIRE EXTINGUISHER INSPECTION': 200,
#          'HOURS; PERMITTED TO BE IN PARK BETWEEN 6AM-1AM (UNLESS OTHERWISE POSTED)': 525,
#          'OTHER PENAL LAW': 9833,
#          'OPERATE PEDICAB WITHOUT BATTERY OPERATED TAIL LIGHTS': 113,
#          'NOISE (DEVICE)': 9093,
#          'STREET, OBSTRUCTED WITH OTHER THAN VEHICLE': 280,
#          'NO PARKING': 59,
#          'UNREASONABLE NOISE; FROM ANY VEHICLE HORN': 132,
#          'UNLICENSED OPERATOR': 3469,
#          'POSS. OF MACE': 1417,
#          'LITTERING': 92630,
#          'NO SECURITY GUARD LICENSE': 4325,
#          'OBSTRUCTED VIEW INTO BAR': 67,
#          'POLICE UNIFORM/EMBLEM; UNLAWFUL USE OF': 29,
#          'UNREASONABLE NOISE (FROM PERSON)': 17,
#          'PICK UP FARE IN STREET PROHIBITED ("CRUISING")': 24,
#          'RECEIVING MONEY OUTSIDE DAZ': 185,
#          'POSSESSION OF A POLICE EMBLEM': 21,
#          'OTHER NAVIGATION LAW': 5594,
#          'UNREASONABLE NOISE; FROM CAR MUFFLER/EXHAUST (HEARD FROM 150 FT AWAY)': 692,
#          'DISOBEY TRANSIT SIGN': 487,
#          'LITTERING FROM VEHICLE': 180,
#          'OBSTRUCTED VIEW': 120,
#          'DISCON: FIGHTING': 96407,
#          'PICK UP HAIL IN BUS STOP': 6365,
#          'POSSESSION OF FIREWORKS': 106,
#          'DOUBLE PARKING': 11,
#          'UNSECURED COMPRESSED GAS TANKS': 66,
#          'OPEN FIRE (CAUSE OR PERMIT)': 116,
#          'IMITATION PISTOL/AIR RIFLE, POSS. OF': 1421,
#          'DISCON: CREATE HAZARDOUS CONDITION': 53190,
#          'NO NAME OR ADDRESS DISPLAYED': 13828,
#          'PEDICAB WITHOUT WHEEL REFLECTORS': 121,
#          'PANHANDLING': 6489,
#          'OBSTRUCTED FIRE EXTINGUISHER': 74,
#          'LICENSE/RECORDS/DOCUMENTS; FAIL TO PRODUCE WHEN REQUESTED': 34,
#          'NOISE (ENGINE EXHUST)': 480,
#          'URINATING IN PUBLIC': 294351,
#          'OTHER TLC': 6410,
#          'POSSESSION OF A BOX CUTTER (20 YES OLD OR YOUNGER)': 158,
#          'SIDEWALK, OBSTRUCTED': 39,
#          'PARK REGULATIONS': 44911,
#          'FAIL TO DISPLAY "CERTIFICATE OF OCCUPANCY"': 56,
#          'TICKET SELLERS OBSTRUCT PED FLOW': 157,
#          'IN A PUBLIC PLACE AND USES ABUSIVE/OBSCENE LANGUAGE OR MAKES AN OBSCENE GESTURE': 138,
#          'NO TRIP SHEET': 10547,
#          'POLICE/PRESS CARD; UNLAWFUL USE OR POSSESSION OF': 24,
#          'NO POSTING WORKERS COMP INS': 215,
#          'UNLICENSED GENERAL VENDOR': 314,
#          'PICK-UP FARE IN BUS STOP': 1440,
#          'UNLICENSED SALE OF ALCOHOL': 3714,
#          'FAILURE TO CONSPICUOUSLY POST "SLA LICENSE" IN A SUITABLE FRAME': 66,
#          'HARASSMENT 2': 4676,
#          'CONSUMPTION OF ALCOHOL IN PARK': 13460,
#          'OCCUPANCY SIGN NOT POSTED': 136,
#          'RADIO, TWO-WAY; PROHIBITED WITHOUT PERMIT': 13,
#          'DRIVE ON SIDEWALK': 273,
#          'TOW TRUCK VIOLATIONS (OTHER)': 1378,
#          'UNLICENSED CABARET, DANCE HALL, OR CATERING HALL': 29,
#          'SPITTING IN PUBLIC': 24855,
#          'NO CPR KIT': 202,
#          'FAIL TO DISPLAY': 53,
#          'POLICE MACE; UNLAWFUL POSSESSION': 115,
#          'UNLAWFUL SALE FOR OFF-PREMISE CONSUMPTION': 13,
#          'PEDESTRIAN FLOW ZONE': 136,
#          'SELLING OUTSIDE DAZ': 220,
#          'FAIL TO MAINTAIN EMERGENCY LIGHTING': 170,
#          'BARBER/HAIRSTYLIST NOT WEARING OUTER COAT OR UNIFORM': 9,
#          'DRIVER CANNOT PRODUCE PROOF OF INSURANCE': 102,
#          'LOITERING (GAMBLING)': 11854,
#          'NOISE (UNREASONABLE)': 70165,
#          'USING EXTENSION CORD AS PERMANENT WIRING': 133,
#          'SELL ALCOHOLIC BEVERAGES WITHOUT LICENSE': 63,
#          'POSSESSION OF ALCOHOL BY A MINOR': 82,
#          'CAB HAILER': 15,
#          'PISTOL, TOY/IMITATION; UNLAWFUL SALE, USE, ETC.': 51,
#          'HANDCUFFS; UNLAWFUL POSSESSION OF (INCLUDES DISP. CINCH & THUMB CUFFS/LEG IRONS)': 17,
#          'UNLAWFUL POSSESSION SYTHETIC CANNABINOIDS': 879,
#          'FAIL TO MAINTAIN MEANS OF EGRESS': 89,
#          'TICKETS OUTSIDE DAZ': 86,
#          'CART MAN, UNLICENSED': 1,
#          'CROSSWALK': 144,
#          'DISCON: OBSTRUCT PEDESTRIAN': 210327,
#          'GLASS BOTTLE/CONTAINER; IN RESTRICTED AREA': 24,
#          'UNATTENDED VEH. (ENGINE RUNNING)': 796,
#          'SMOKING IN AN ENCLOSED SPACE FOR 50 OR MORE PEOPLE': 45,
#          'PERMIT ON-PREMISE CONSUMPTION': 82,
#          'REFUSE INSPECTION BY POLICE': 90,
#          'KNIVES; DISPLAYED OUTSIDE CLOTHING/CARRY IN THE OPEN WITHOUT A LAWFUL PURPOSE': 373,
#          'PRICES OF ALCOHOL NOT DISPLAYED': 30,
#          'SMOKING IN A SUPERMARKET': 9,
#          'VENTILATION GRILL, CELLAR DOOR, MANHOLE COVER (STANDING OVER)': 4,
#          'NOISE (HORN/ALARM)': 4214,
#          'FAIL TO POST SIGN - "PROHIBITED SALE TO MINOR/INTOX PERSON"': 50,
#          'SALE OF SPRAY PAINT/BROAD TIPPED MARKER(TO PERSON UNDER 21 YEARS OLD)': 4,
#          'TOW:UNAUTHORIZED REMOVAL OF VEHICLE': 208,
#          'FAIL TO COMPLY WITH VACATE ORDER': 7,
#          'TICKET SELLER WITHIN 10 FT OF X-WALK': 18,
#          'SALE OF LOOSE CIGARETTES': 170,
#          'VEHICLE; RIFLE/SHOTGUN/AMMO IN': 7,
#          'OTHER PARK REGS': 28286,
#          'ILLEGAL BOTTLE CLUB': 2552,
#          'UNLEASHED DOG WITH LEASH OVER 6 FEET': 13,
#          'FAIL TO CONTROL CROWD': 58,
#          'DCA PEDICAB DRIVERS LICENSE NOT VISABLE': 99,
#          'REVOCATION OR SUSPENSION': 8287,
#          'SALE OF ALCOHOL TO A MINOR': 3673,
#          'UNREASONABLE NOISE; GENERAL': 207,
#          'UN-MOUNTED FIRE EXTINGUISHER': 120,
#          'MISSING EQUIPMENT': 38,
#          'SALE BETWEEN 3AM-12PM ON SUNDAY': 1,
#          'UNREASONABLE NOISE FROM A LICENSED PREMISE': 50,
#          'FAIL TO CLEAN CANINE WASTE': 44,
#          'NO TOW LICENSE': 42,
#          '20-217(I)': 29,
#          'UNAUTHORIZED POSTING (SIGNS/FLYERS)': 22,
#          'LITTERING PROHIBITED': 147,
#          'FAILURE TO POST "PREGNANCY WARNING SIGN"': 86,
#          'DEFECTIVE BREAKLIGHT': 547,
#          'URINATE/DEFICATE IN PARK': 1613,
#          'FOOD PROTECTION/STORAGE/TRANSP': 792,
#          'MERCHANDISE, SALE OF PROHIBITED': 3,
#          'OTHER ACA': 84,
#          'STREET NUMBERS (ADDRESS) NOT DISPLAYED OUTSIDE': 4,
#          "APPROPRIATE DRIVER'S LICENSE": 13,
#          'AGGRESSIVE PANHANDLING': 108,
#          'SOUND DEVICE; ADVERTISING PURPOSES': 120,
#          'FAILURE TO YIELD AT INTERSECTION': 76,
#          'UNSOLICITED RESPONSE TO ACCIDENT SCENE': 40,
#          'NO PARKING (EXCEPT AUTH. VEHICLES)': 47,
#          'CROSS MIDDLE OF BLOCK WITH LIGHT SIGNALS AT BOTH ENDS OF STREET': 28,
#          'TICKET SPECULATION (RESELL TICKET TO A VENUE WITH A CAPACITY OF >5000 WITHIN 100': 5,
#          'IN PUBLIC UNDER DRUGS': 214,
#          'FAIL TO MAINTAIN PROPRIETARY SECURITY GUARD LICENSE': 94,
#          'FAILURE TO SURRENDER LICENSE OR REGISTRATION': 891,
#          'BOUNCER (SECURITY GUARD) WITHOUT A VALID REGISTRATION CARD': 57,
#          'DISCON: UNREASONABLE NOISE': 68352,
#          'UNLAWFUL EVICTION': 245,
#          'UNLICENSED BARBER': 53,
#          'GRAFFITI PROHIBITED; PUBLIC/PRIVATE BUILDING/PROPERTY (INCLUDES STICKER/DECAL)': 4,
#          'INSPECTION; PEDICAB REGISTRATION PLATE': 49,
#          'POSSESSION OF A REPLICA NYPD SHIELD': 8,
#          'FIRE WITHOUT PERMIT': 1163,
#          'COUNTERFEIT INSPECTION STICKER': 40,
#          'UNTAXED BEVERAGE POSSESS/CONTROL': 27,
#          'LOITERING (TRANSPORTATION FACILITY/SLEEPING)': 78,
#          'SALE OF TOBACCO/ROLLING PAPERS TO MINOR': 11,
#          'USE OF ROADWAYS, PEDESTRIANS, HORSES, BICYCLES AND LIMITED USE VEHICLES PROHIBIT': 68,
#          'STRIKE, SHOVE, KICK, OR THREATEN/ATTEMPT': 95,
#          'CONTAINER, NOT ORIGINAL OR TAMPERED': 75,
#          'FAILURE TO YIELD TO PEDESTRIAN IN CROSSWALK': 378,
#          'DAZ RULES VIOLATED  CHARACTER': 68,
#          'SMOKING IN ELEVATOR': 9377,
#          'ONE WAY STREET': 1590,
#          'BOOK TO BE OPEN TO INSPECTION': 19,
#          'LITTER FROM A VEHICLE': 5,
#          'EXIT NOT TO STREET OR BLOCKED FROM STREET': 18,
#          'IMPROPER TURN': 210,
#          'UNLICENSED VEHICLE; KNOWINGLY OPERATE FOR HIRE': 3,
#          'ALCOHOLIC BEVERAGE; CONSUME/POSSESS WITH INTENT TO CONSUME BY SELF/OTHERS': 34,
#          'NO COVERED GARBAGE, USED SOLELY FOR TOWELS AND LINENS': 3,
#          'VENDOR: UNLICENSED': 60086,
#          'NO "NO CHOKING" SIGN IN FOOD ESTABLISHMENT': 11,
#          'SALE AFTER HOURS (4AM-8AM, MON-SAT)': 42,
#          'IMPROPER REGISTRATION': 57,
#          'DRIVER DOES NOT POSSESS "FOR HIRE-VEHICLE" LICENSE': 16,
#          'BEVERAGES NOT ON LICENSE': 9,
#          'FOLLOW IN A PUBLIC PLACE': 14,
#          'VACANT LOT; MOTOR VEHICLE PARKED IN': 7,
#          'SERIOUSLY ANNOY WITHOUT A LEGITIMATE PURPOSE': 73,
#          'OTHER NYS WORK COMP': 113,
#          'ADVERTISE AS HACK WITHOUT LICENSE': 89,
#          'BOTTLE CLUB; OPERATE UNLAWFULLY': 91,
#          'NO CHAUFFEURS LICENSE (CLASS E)': 13563,
#          'EXCAVATION (VEHICLE OBSTRUCTING TRAFFIC)': 16,
#          'FAILURE TO DISPLAY PEDICAB REGISTRATION OR PEDICAB DRIVER?S LICENSE': 16,
#          'EXIT LIGHT INOPERABLE': 44,
#          "LICENSE, TOW OPERATOR'S; OPERATE/ASSIST WITHOUT": 60,
#          'AUTHORIZED FIRE; NOT PROPERLY CONTAINED': 8,
#          'OVERCROWDED': 66,
#          'NO SMOKING SIGN/ NOT POSTED AT ENTRANCE': 53,
#          'SALE/PURCHASE/USE OF ALCOHOL BY MINOR': 23093,
#          'DOING BUSINESS UNDER NAME OTHER THAN ON LICENSE': 2,
#          'UNLICENSED TICKET SELLING': 29,
#          'CROSSWALK/DRIVEWAY/ETC, WITHIN 10 FEET': 24,
#          'POLICE RADIO IN AUTO (UNLESS PERMISSION OF POLICE COMMISSIONER IS GRANTED)': 24,
#          'SALE OF TOBACCO TO MINORS (UNDER 18 YEARS OLD)': 40,
#          'SMOKING IN A STORE': 121,
#          'WITHOUT LAWFUL AUTHORITY, DISTURBS ANY LAWFUL ASSEMBLY OR MEETING OF PERSONS': 101,
#          'NO TAX STAMP, NYC': 5,
#          'RED LIGHT (DISOBEY)': 1672,
#          'ONLY 1 EXIT AND OCCUPIED BY MORE THAN 75 PEOPLE': 17,
#          'OWNER UNLICENSED': 3,
#          'NO FLAME PERMIT FOR CANDLES': 29,
#          'UNLICENSED TICKET SELLER': 53,
#          'BUS STOP, OBSTRUCT': 9,
#          'NO DOG LICENSE (COLLAR)': 33,
#          'FIRE HYDRANT, OBSTRUCT': 43,
#          'PEDICAB WITHOUT OPERATIONAL SIGNAL': 82,
#          'UNLICENSED VENDOR': 192,
#          'SIGNED AUTHORIZATION BY OWNER/POLICE, TOW WITHOUT (REPORT OF VIOLATION PREPARED)': 6,
#          'FAIL TO SECURE WORKERS COMP INS.': 113,
#          'EXCEEDING 12 INCHES FROM CURB': 568,
#          'VENDOR: DISP MERCHANDISE ON SIDEWALK': 10601,
#          'FAIL TO DISPLAY CERTIFICATE OF AUTHORITY': 45,
#          'RULES': 17,
#          'ACCEPTING IMPROPER ID (EX: COLLEGE ID)': 8,
#          'FAILURE TO DISPLAY "BUSINESS CERTIFICATE"': 64,
#          'UNLICENSED SECOND BAR': 37,
#          'RATES, TOWING; EXCEED AUTHORIZED LIMITS': 4,
#          'UNLICENSED BARBERSHOP': 9,
#          'NO CPR KIT SIGN': 89,
#          'MARIJUANA, UNLAWFUL POSSESSION 1ST DEGREE': 279,
#          'OPEN HYDRANT': 752,
#          'FIRE HYDRANT, NEAR': 9,
#          'TOW:SOLICITING TOW AT SCENE OF ACCIDENT': 837,
#          'POSS. OF RADIO ABLE TO RECEIVE POLICE FREQUENCIES W/O PERMIT FROM POL COMMIS.': 28,
#          'DOG: FAILURE TO REMOVE CANINE WASTE': 6407,
#          'CLEAN/WASH/POLISH/OFFER TO PASSENGER VEHICLE': 8,
#          'TRIP SHEET; WITH REQUIRED IDENTIFICATION, DISPATCH INFO AND READINGS': 23,
#          'UNREASONABLE NOISE; FROM MOTORCYCLE MUFFLER/EXHAUST (HEARD FROM 200FT AWAY)': 18,
#          'BARE HAND CONTACT (FOOD)': 1108,
#          'PARKING PROHIBITED': 5,
#          'SOUND DEVICE; NON-COMMERCIAL WITHOUT PERMIT': 86,
#          'SOUND REPRODUCTION DEVICE-NO PERMIT': 1195,
#          'CURTAIN PLACED OVER EXIT DOOR': 34,
#          'FAIL TO DISPLAY VALID BUSINESS CERTIFICATE': 56,
#          'TOW TRUCK; RATE/INFO; SIGN NOT POSTED': 30,
#          'NO "CERTIFICATE OF OCCUPANCY"': 17,
#          'LOITERING (SCHOOL)': 4708,
#          'PAVEMENT MARKING (DISOBEY)': 326,
#          'PASSENGER PICK UP IN OMNIBUS FASHION': 3,
#          'CONTAMINATED LIQUORS (EX: FRUIT FLIES IN BOTTLE)': 12,
#          'OTHER THAN CLEAR GLASS WINDOWS': 14,
#          'INVALID PROOF OF INSUR.': 753,
#          'LITTERING (DUMPING RUBBISH AND REFUSE)': 17,
#          'LIQUIDS (NOXIOUS); POUR/DISCHARGE': 24,
#          'POSSESSION OF AIR PISTOL/RIFLE': 99,
#          "CHAUFFER'S LICENSE, OPERATE WITHOUT (NYS OR SIMILAR OF RESIDENT STATE)": 3,
#          'FAIL TO DISPLAY "CABARET LICENSE"': 8,
#          'MEDALLION PLATE; NONE/INSECURE': 26,
#          'LOITERING (TRANSPORTATION FACILITY)': 122,
#          'UNLICENSED DOG': 16,
#          'REFUSAL TO TOW; WITHIN NYC, UNJUSTIFIABLE (REPORT OF VIOLATION PREPARED)': 9,
#          'NO MEDALLION': 291,
#          'RECORDS': 7,
#          'VEHICLE IN PARK': 5985,
#          'UNREASONABLE NOISE (FROM SOUND REPRODUCTION DEVICE)': 12,
#          'UNDERAGE DRINKING': 13824,
#          'VENDOR: (OTHER)': 22037,
#          'TRIP SHEET; WITH REQUIRED TRIP ENTRIES AND READINGS': 25,
#          'NO BUSINESS CERTIFICATE': 3108,
#          'SMOKING ANYPLACE WITH COMBUSTIBLES PRESENT (EX: GAS STATION)': 2,
#          'RECKLESS OPERATION (REPORT OF VIOLATION PREPARED)': 12,
#          'ERECT A SHED': 24,
#          'SMOKING IN A THEATER/MUSEUM/LIBRARY/HOSPITAL': 3,
#          "TAXICAB DRIVER'S LICENSE; IN APPROPRIATE FRAME": 27,
#          'NO PREGNANCY WARNING SIGN': 1910,
#          'CONTAMINATED ALCOHOL/FOOD': 26,
#          'PEDICAB WITHOUT 311 AND REGISTRATION SIGN': 52,
#          'FAILURE TO DISPLAY "LIQUOR LICENSE"': 26,
#          'PASSING ON LEFT': 18,
#          'FAILURE TO CONTROL CROWD': 44,
#          'FAIL TO DISPLAY SERVICE PRICES': 17,
#          'DISORDERLY BEHAVIOR (ENDANGERS SAFETY)': 4,
#          'RESTRICTED AREA': 5,
#          'SIGNS, UNAUTHORIZED; TAXI, ETC': 20,
#          'NO "AMUSEMENT ARCADE LICENSE"': 10,
#          'CROSSWALK/DRIVEWAY, ETC': 14,
#          'LEAVING THE SCENE OF AN ACCIDENT (PROP. DAM.)': 513,
#          'FAILURE TO NOTIFY A PRECINCT WITHIN 2 HOURS OF TOWING A VEHICLE WHEN OWNER IS UN': 1,
#          'RESTRICTIONS; FAIL TO COMPLY WITH': 52,
#          'OTHER ENVIRONMENTAL CONSERVATION LAW': 327,
#          'LICENSE, ENGAGE IN TOWING BUSINESS WITHOUT': 30,
#          'RECEIPT; FAIL TO PROVIDE IF REQUESTED': 3,
#          "SCHOOL GROUNDS/SCHOOL BUS/CHILDREN'S OVERNIGHT CAMP WITHOUT LEGITIMATE REASON": 2,
#          'UNAUTHORIZED POSTING': 3326,
#          'CONSUMPTION OF ALCOHOL IN VEHICLE': 460,
#          'HIGHWAY/PARKWAY; UNAUTHORIZED TOW': 4,
#          'PATH, LEAVE LESS THAN 12 FEET (ON SIDEWALK)': 7,
#          'BUS STOP/TAXI STAND, IN': 8,
#          'REFUSE TO TRANSPORT (WITHIN NYC)': 14,
#          'DRIVER DOES NOT POSSESS "FOR HIRE-VEHICLE" DRIVER\'S LICENSE': 13,
#          'UNLICENSED CABARET': 1521,
#          'NO EXIT SIGN AT DOOR OR NOT CLEARLY MARKED': 27,
#          'STREET NUMBER NOT DISPLAYED ON ANY BUILDING': 3,
#          'FAIL TO DISPLAY BARBERS/BARBERSHOPS LICENSE': 14,
#          'FAIL TO POST "NO SMOKING" SIGNS WHERE REQUIRED': 19,
#          'DISORDERLY BEHAVIOR (OBSTRUCTS TRAFFIC)': 5,
#          'PLACE/TIME PROHIBITED': 15,
#          'EXIT DOOR SWINGS IN': 88,
#          'HEADREST NOT COVERED WITH TOWEL OR PAPER TOWEL': 12,
#          'NO SMOKING SIGN POSTED': 23,
#          'DISORDERLY BEHAVIOR (SEXUAL ACTIVITY)': 11,
#          'NO BARBERS LICENSE': 867,
#          'EMPLOYMENT OF A MINOR': 3,
#          'REFUSAL TO TOW; VEHICLE OBSTRUCTING TRAFFIC (REPORT OF VIOLATION PREPARED)': 2,
#          'FIRE HYDRANT': 65,
#          'DUMPING': 737,
#          'STOP SIGN': 185,
#          'DISCON: DISTURB LAWFUL ASSEMBLY': 2870,
#          'VENDOR: FAIL TO DISPLAY PRICES': 2747,
#          'UNLAWFULLY POSTING ADVERTISEMENTS': 1265,
#          'NO "DCA CIGARETTE LICENSE"': 10,
#          'NO SMOKING SIGNS NOT POSTED': 3788,
#          'LOITERING (UNCLASSIFIED)': 629,
#          'ALLOW GAMBLING - INSIDE BILLIARD HALL': 5,
#          'POWER DEVICE, ILLEGAL USE OF (GAS/ELECTRIC)': 1,
#          'PATH, LEAVES LESS THAN 12 FT. (ON SIDEWALK)': 6,
#          'POSSESSION OF A WILD ANIMAL': 12,
#          'SOLICITATION OF PEDESTRIANS BY MERCHANT': 15,
#          'ALCOHOL, UNDER INFLUENCE OF (MAY ENDANGER ANYONE/PROPERTY)': 40,
#          'CAR/STAND; OVER 8 FEET LONG, 3 FEET WIDE': 5,
#          'PEDESTRIAN WALKING INTO TRAFFIC UNSAFELY': 46,
#          'FAIL TO COMPLY WITH THE DIRECTIONS OF A POLICE OFFICER': 17,
#          'FOLLOWING TOO CLOSELY': 18,
#          'LOCKED/BOLTED/FASTENED DOOR': 7,
#          'ENGAGED IN ANY FORM OF SEXUAL ACTIVITY': 17,
#          'STREET; OBSTRUCT WITHOUT PERMIT': 7,
#          'UNLICENSED REPAIR SHOP': 52,
#          'NO DOG LICENSE (PAPER)': 16,
#          'FAIL TO WEAR WHILE VENDING': 25,
#          'FAILURE TO DISPLAY VALID NYS "TAX CERTIFICATE OF AUTHORITY"': 1,
#          'OBSTRUCTING TRAFFIC': 482,
#          'EMPLOYMENT OF A FELON': 9,
#          'SALE OUT OF CLASS': 25,
#          'PRACTICE OF BARBERING W/O A LICENSE': 1002,
#          'UNLAWFUL PREVENTION OF PUBLIC ACCESS TO RECORDS': 78,
#          'ADVERTISE, EXTERIOR, WITHOUT PERMIT': 7,
#          'UNSEALED BOTTLE, LIQUOR/WINE IN AREA (EXCEPT WINE TASTING)': 9,
#          'AMMUNITION; UNLAWFUL SALE/PURCHASE': 16,
#          'BENCH; OBSTRUCT USE FOR OTHER PERSONS': 26,
#          'POSSESSION OF A POLICE SCANNER': 10,
#          'OPERATE MOTOR VEHICLE IN AN UNAUTHORIZED AREA': 27,
#          'FAIL TO COMPLY WITH ORDER': 430,
#          'EXIT DOOR BLOCKED': 62,
#          'NO OPEN FLAME PERMIT': 42,
#          'ALLOW ALCOHOL OUTSIDE': 5,
#          'RIFLE, SHOTGUN, AMMO SALE OR PURCHASE': 151,
#          'REGULATIONS, VIOLATE PARKING': 11,
#          'NO CIGARETTE LICENSE': 18,
#          'CLIMB WALL/FENCE/TREE': 3,
#          'PARK DEPARTMENT PROPERTY; WITHOUT AUTHORIZATION': 12,
#          'NO CERTIFICATE OF OCCUPANCY': 333,
#          "SOLICIT GUARDING OF ANOTHER'S VEHICLE": 18,
#          'TAKE OFFS AND LANDING': 36,
#          'NO "BILLIARD & POCKET-BILLIARD ROOM LICENSE"': 6,
#          'UNLICENSED TAXI DRIVER; PERMIT TO OPERATE FOR HIRE': 11,
#          'OFFENSIVE EXHIBITION': 179,
#          'NO CERTIFICATE OF AUTHORITY': 13829,
#          'TRANSIT FACILITY FOR COMMERCIAL OR ENTERTAINMENT PURPOSE': 3,
#          'FIREWORKS': 4161,
#          'PERSONAL USE; FAIL TO COMPLY REGARDING TRIP SHEET AND LIGHT': 5,
#          'NO SIGN STATING "CIGARETTE(TOBACCO PRODUCTS)SALE TO PERSONS UNDER 18 PROHIBITED"': 9,
#          'BICYCLE (OTHER)': 353,
#          'VEHICLE DISMANTLER FAILED TO KEEP PROPER RECORDS': 1,
#          'FAILURE TO PRODUCE THE LAST 20 ITEMS FOR INSPECTION': 2,
#          'VEND:RESTRICTIONS ON PLCMENT VEH/PUSHCARTS': 16827,
#          'FAILED TO DISPLAY BARBER LICENSE': 612,
#          'SAFETY BELT (CHILD)': 20,
#          'BUILD/MAINTAIN/USE; OTHER THAN DESIGNATED LOCATION OR WITHOUT A PERMIT': 6,
#          'PUSHCART/STAND/VEHICLE (PERMIT REQUIRED)': 10,
#          'NO NYC LICENSE TO SELL CIGARETTES': 25,
#          'SCHOOL BUS, PASSING STOPPED': 31,
#          'VENDOR WITHOUT A LICENSE (EXCEPT NEWSPAPERS, PERIODICALS, BOOKS/PAMPHLETS, ETC)': 5,
#          'OPERATE BIKE ON SIDEWALK *(NOT A C SUMMONS)*': 9,
#          'BUSINESS NAME NOT DISPLAYED OUTSIDE': 9,
#          'BICYCLE IN PLAYGROUND; RIDE ON': 2,
#          'PARKED MOTOR VEHICLE, SALE FROM': 5,
#          'POSSESS WITHOUT PERMIT': 9,
#          'OPERATE BICYCLE IN A RECKLESS MANNER': 9,
#          'DISORDERLY PERSON IN PARK': 2148,
#          'COMPRESSED GAS STORED ON PREMISE': 8,
#          'DOG: UNLICENSED': 14253,
#          'NO CERTIFICATE OF FITNESS FOR AIR COMPRESSOR': 2,
#          'UNAUTHORIZED SIGNS (TAXI, CAR SERVICE)': 2154,
#          'PEDI CAB WITHSEATING FOR MORE THAN 3 PASSENGERS': 11,
#          'NO SANITARY SOAP DISPENSER': 2,
#          'SIGNS; FAIL TO OBEY PERTINENT (BICYCLE)': 13,
#          'UNLEASHED ANIMAL': 17,
#          'STREET NUMBERS (ADDRESS) NOT DISPLAYED ON THE OUTSIDE': 6,
#          'SMOKING IN A CLASSROOM/LECTURE HALL': 1,
#          'ANIMAL/DOG IN PLAYGROUND/PICNIC AREA': 3,
#          'RECEPTACLES; SPILLING FROM': 1,
#          'UNSEALED BOTTLE PRESENT': 15,
#          'INSURANCE STAMP EXPIRED': 1671,
#          'BIKE IN PARK': 4708,
#          'LITTER/CLUTTER AROUND BUILDING': 8,
#          'ANIMAL BEING A NUISANCE': 5,
#          'CURB, AWAY FROM': 4,
#          'UNAUTHORIZED USE OF POLICE INSIGNIA': 88,
#          'OTHER NYS EDUCATION LAW': 46,
#          'PROMOTING EXPOSURE': 412,
#          'LICENSE ALTERED/DEFACED/DESTROYED': 8,
#          'DEFECTIVE; FAIL TO LIGHT "OFF-DUTY" LOCK REAR DOORS, MAKE REQUIRED ENTRIES': 1,
#          'UNSAFE LANE CHANGE': 182,
#          'POSSESSION OF A SIREN': 5,
#          'FAIL TO SURRENDER': 1,
#          'DIRTY/OBSTRUCTED SIDEWALK': 10,
#          'SOLICIT PASSENGER; WORDS OTHER THAN "TAXI", "CAB", OR "TAXICAB"': 1,
#          'CLOSE ANY STREET/PORTION, WITHOUT PERMIT': 1,
#          'UNSWEPT/UNMOPPED FLOOR': 7,
#          'UNINSURED TOW TRUCK': 10,
#          'REPAIR AT SCENE, OFFER TO MAKE OR ESTIMATE COST OF': 2,
#          'OCCUPIED BY OVER 75 PATRONS & NO SPRINKLER SYSTEM': 1,
#          'TICKET SPECULATION: 1-4 TICKETS': 4,
#          'REG. STICKER MISSING/EXPIRED': 62,
#          'ANNOY, SERIOUSLY; UNREASONABLE ALARM': 1,
#          'STREET, SWEEP INTO': 2,
#          'UNLICENSED GARAGE/PARKING LOT': 2,
#          'PREVENT CLEAR VIEW INTO LIQUOR STORE': 8,
#          'DOG FECES, FAIL TO REMOVE PROMPTLY (DOES NOT APPLY TO A GUIDE DOG)': 5,
#          'BROKEN WINDSHIELD': 122,
#          'FAIL TO DISPLAY HAIRSTYLIST/NAIL TECH/COSMETOLOGISTS LICENSE': 3,
#          'OTHER MULTIPLE DWELLING': 1114,
#          'POLICE RADIO OR EQUIPMENT': 94,
#          'NO COVERED GARBAGE, USED SOLELY FOR HAIR/PAPER/WASTE MATERIAL': 6,
#          'UNLICENSED HAIRSTYLIST/NAIL TECH/COSMETOLOGIST': 2,
#          'EXIT DOOR LESS THAN 36" WIDE': 2,
#          'HAIR ON FLOOR': 7,
#          'CARRY/POSSESS IN PUBLIC; UNLOADED & UNCONCEALED': 11,
#          'WINDOW, AGAINST DISPLAY': 2,
#          'DISGUISED IN AN UNLAWFUL MANNER WITHOUT REASON (MASKED)': 8,
#          'LOITERING FOR DRUGS IN A PARK': 15,
#          'DOING BUS W/OTHER NAME': 341,
#          'PROHIBITED SALE': 10,
#          'FAILURE TO TIMELY CREATE ELECTRONIC RECORD': 2,
#          'FALSE LABELS ON MERCHANDISE': 2,
#          'FAIL TO POST CIGARETTE HEALTH SIGNS': 4,
#          'INSURANCE': 2,
#          'CARRY/POSSESS IN PUBLIC; LOADED': 12,
#          'EVICTION; UNLAWFUL (USE OR THREATEN THE USE OF FORCE)': 4,
#          'UNAUTHORIZED RADIO': 1343,
#          'DESTINATION; FAIL TO PLACE & KEEP IN NON-RECORDING POSITION UNTIL PAID': 2,
#          'UNLICENSED SIDEWALK CAF': 1,
#          'WINDOW WASHER': 4,
#          'IN A BUS STOP': 1,
#          'UNSAFELY BACKING': 160,
#          'DOG IN PARK': 1520,
#          'TICKET SPECULATION': 5264,
#          'NOISE (ENGINE EXHAUST)': 39835,
#          '': 1833,
#          'UNAUTHORIZED FOR HIRE': 467,
#          'SEX IN PARK': 1970,
#          'MOTORCYCLE (OTHER)': 92,
#          'VENDOR: OVERSIZE TABLE': 1079,
#          'UNINSURED VEHICLES FOR HIRE': 3063,
#          'BICYCLE NO BRAKES': 30,
#          'CRUISING': 391,
#          'VENDING ON PARKING METER': 4134,
#          'GRAFFITI': 561,
#          'BICYCLE NO SAFETY HELMET': 416,
#          'CRUISING PROHIBITED - MEDALLION': 8829,
#          'DOG: NO VACCINATION': 3709,
#          'LITTER BASKETS; IMPROPER USE OF': 2,
#          'TAXI-NO METER': 578,
#          'TRUANCY': 2053,
#          'FAIL TO YIELD FOR EMERGENCY VEHICLE': 209,
#          'BICYCLE NO BELL': 315,
#          'UNAUTHORIZED COLOR (TAXI YELLOW)': 220,
#          'BICYCLE NO LIGHTS': 56,
#          'REVOKED/SUSPENDED/EXPIRED, OPERATE WHILE': 25,
#          'OTHER GENERAL BUSINESS LAW': 4406,
#          'DRIVE THRU BARRIER': 8,
#          'DEF FIRE EXTG': 6,
#          'EXHST LK': 4,
#          '140': 257,
#          'LK ANTIFZ': 1,
#          'CRACK WNSHLD': 2,
#          'PEDICAB BUSINESS LICENSE': 2,
#          '16-118': 2,
#          'DEF FT ID LT': 16,
#          'UNCOV BATTERY': 36,
#          'NO PLT LT': 10,
#          'DEF D/S MIRROR': 8,
#          'NO DOT #': 191,
#          'DEF EXHAUST PIPE': 2,
#          'no dot #': 10,
#          'CFR': 129,
#          'BK LININGS': 2,
#          'STL': 58,
#          'NO FLARES': 166,
#          'SUSP. REG.': 12,
#          'OPEN CONTAINER': 1941,
#          'UNLAWFUL ASSEMBLY': 1,
#          'OCA': 486,
#          'NYSTL': 57,
#          'DOG: NO TAGS': 13,
#          'BALD TIRE': 3,
#          'LOITERING': 1264,
#          'SMOKING IN PUBLIC PLACE': 1578,
#          'NO PLATE': 2449,
#          'SEATBELT': 102,
#          'OTHER ABC VIOLATION': 725,
#          'DISCONDUCT': 402,
#          'OBSTRUCTING FIRE HYDRANT': 11,
#          'EXPOSURE': 782,
#          'trespass': 64,
#          'IN PARK FROM 1AM TO 6AM': 133,
#          'DISCON': 374,
#          'OTHER': 56,
#          'OPEN ALCOHOL CONTAINER IN PUBLIC': 1125,
#          'FOLLOWING TO CLOSELY': 10,
#          'OPEN CONT': 155,
#          'PARK RULES: UNCLASSIFIED': 1424,
#          'NO AM LICENSE': 1,
#          'EXCLUSIVE AREA': 77,
#          'CELL PHONE,IMPROPER USE OF': 1,
#          'POSS. OF MARIJUANA': 11,
#          'DISOBEY RED LIGHT': 237,
#          'NO ID': 3402,
#          'DOG: UNLICENSED PAPER': 25,
#          'reckless driving': 24,
#          'DSICON': 2,
#          'DIS CON': 125,
#          'DISOBEY PAVEMENT MARKING': 94,
#          'NO C OF A': 11,
#          'GRAFFITI; SELL MARKER/SPRAY TO PERSON UNDER 21 YEARS OLD': 5,
#          'DEF CLEAR LTS': 4,
#          'PERMIT SEXUAL EXPOSURE': 7,
#          'UNLICENSED STREET ENTERTAINER': 4,
#          "ENTRANCE, WITHIN 20 FT OF ANOTHER'S": 5,
#          'CAP ON PEDICABS': 3,
#          'SAFETY BELT (ADULT)': 113,
#          'MOTORCYCLE HELMET REQUIRED': 33,
#          'POSSESSION OF A LASER POINTER (18 YRS OLD OR YOUNGER IN PUBLIC PLACE)': 2,
#          'NO STANDING': 60,
#          'NO CERTIFICATE OF FITNESS FOR TORCH': 11,
#          'AGGRESSIVE PANHANDLING OF MOTOR VEHICLE OR AGGRESSIVE SALE': 4,
#          'ENTRY FROM OTHER PORTION OF BUILDING': 3,
#          'DISCRIMINATION (REFUSE TO SELL)': 3,
#          'FENCED/ENCLOSED AREA, ALLOW CHILD/ANIMAL IN': 3,
#          'SMOKING': 118,
#          'BUSINESS SOLICITATION OF PEDESTRIANS BY PULLERS-IN (AGGRESSIVE)': 1,
#          'DUMPING BY; OPERATOR OR OWNER OF A VEHICLE': 3,
#          'UCAP': 21,
#          'ALLOW GAMBLING': 7,
#          'AIR LEAK': 17,
#          'NO STANDING (AUTH. VEHICLES)': 12,
#          'METER OPERATING; TAMPER WITH METER/SEALS/CONNECTION/WIRING/TIRES TO AFFECT': 1,
#          'DEFECTIVE; PICK-UP/TRANSPORT PASSENGERS WHEN': 1,
#          'LIQUOR STORE FAILED TO PAINT LICENSE # ON FRONT WINDOW': 3,
#          'SALE AFTER HOURS (4AM-12PM, SUN)': 3,
#          'ANGLE PARKING': 2,
#          'CAMPING WITHOUT A PERMIT': 2,
#          'DISPLAY; UNLAWFULLY': 1,
#          'UNHYGIENIC USE OF THE FOUNTAIN OR POOL AREA': 1,
#          'OTHER AGRICULTURE & MARKETS LAW': 385,
#          'FAIL TO MAINTAIN PROPRIETARYSECURITY GUARD LICENSE': 33,
#          'PLACE/TIME PROHIBITED (SPECIFIC LOCATIONS & TIMES IN MANHATTAN)': 1,
#          'OPERATE MOTOR VEHICLE AND FAILS TO USE DUE CARE FOR ANIMAL (B SUMMONS)': 1,
#          'POSSESSION OF A LASER POINTER (20 YRS OLD OR YOUNGER ON SCHOOL PREMISES)': 3,
#          'ENGINE IDLE; CAUSE/PERMIT MORE THAN 3 MINUTES': 7,
#          'SWEEP ITEMS INTO STREET': 4,
#          'OPENING ENTRIES; FAIL TO SIGN AND CERTIFY': 1,
#          'VACANT LOT; TRAILER, AUTO/HOUSE, PARK': 1,
#          'OVERCHARGE/ATTEMPT; FARE SET BY TLC': 1,
#          'SAFETY ZONE': 6,
#          'REPORTING': 4,
#          'TOW:PD RADIO/SCANNR-TOW TRUCK/ON PERSON': 98,
#          'ROLLER SKATE; OTHER THAN DESIGNATED AREA': 2,
#          'PRICE, FAILS TO DISPLAY': 5,
#          'USED PAPER TOWELS/PAPER/OTHER MATERIALS NOT IN GARBAGE': 1,
#          'PARKING PROHIBITED, WHERE': 2,
#          'REGISTRATION CERTIFICATE; POSSES WITHOUT': 4,
#          'ALCOHOL BEVERAGE; CONSUME WHILE DRIVING/OCCUPYING': 1,
#          'SMOKING ON A BUS': 1,
#          'PERMIT; FAIL TO PROPERLY POST': 2,
#          'UNREASONABLE NOISE; FROM AN ANIMAL(7AM-10PM)CONTINUOUSLY FOR 10MIN OR MORE': 4,
#          'SIGNS, UNAUTHORIZED': 1,
#          'FRAUDULENT ACCOSTING': 12,
#          'VENDING: NO TAX STAMP': 5358,
#          'STREET NUMBERS NOT DISPLAYED PROPERLY; ANY BUILDING': 2,
#          'SIDEWALK; DIRTY': 2,
#          'NO STANDING (BUS STOP)': 84,
#          'NOT IN A BIKE LANE OR IN THE RIGHT HAND SIDE OF TRAFFIC': 1,
#          'LOITERING (MASKED/DISGUISE)': 154,
#          'LOST/STOLEN; FAIL TO NOTIFY WITHIN 72 HOURS': 1,
#          'UNREASONABLE  SPEED': 20,
#          'COMMERCIAL VEHICLE PARKED OVERNIGHT': 39,
#          'HAZING 2': 17,
#          'LOITERING (SEXUAL CONDUCT)': 283,
#          'NO STANDING (BUS LANE)': 53,
#          'FAIL TO YIELD AT LEFT TURN': 14,
#          'INTERSECTION': 26,
#          'VIOLATE RESTRICTED USE LICENSE': 99,
#          'NOISE (ANIMAL)': 91,
#          'WINDSHIELD WASHERS': 116,
#          'SPEEDING': 66,
#          'U-TURN': 131,
#          'MISUSE OF DEALER PLATES': 81,
#          'SAFETY BELT (NO CHILD SEAT)': 31,
#          'WRONG WAY': 27,
#          'FOR SALE SIGN DISPLAYED': 3,
#          'BICYCLE NO REFLECTOR VEST': 38,
#          'VIOLATE LEARNERS PERMIT': 24,
#          'LOITERING (BEGGING)': 121,
#          'NO PARKING (STREET CLEANING)': 4,
#          'PASSING ON RIGHT': 39,
#          'INSPECTION STKR. (MISSING/EXPIRED)': 14,
#          'PARK ON SIDEWALK': 17,
#          'METER (BROKEN)': 4,
#          'TOW TRUCK VIOLATIONS': 369,
#          'NO VENDING MACH. DISCLOSURE': 14,
#          'MISSING/IMPROPER PLATES': 12,
#          'CROSSED DOUBLE YELLOW TO PASS': 15,
#          'OBSTRUCTING DRIVEWAY': 5,
#          'VENDOR: BEYOND MARKET SPACE': 12,
#          'STORAGE 24HR COMMERICAL VEHICLES': 1,
#          'IMPROPER DISPLAY REG. STKR.': 4,
#          'NO DOT #S': 55,
#          'UNSECURED LOAD': 51,
#          'DEF F/T ID': 1,
#          'NO SAFTY TRI': 5,
#          'UNCOVERED BATTERY': 59,
#          'SAFETY ZONE DIRECTION': 8,
#          'NYS TRANSPORTATION LAW': 630,
#          'RECKLESS LY RIDE BIKE ON SIDEWALK': 1,
#          'NO COMMERCIAL ID': 71,
#          'DROP AXLE IN TIRE DEFECTIVE': 1,
#          'OPEN CONT OF ALCOHOL': 1108,
#          'VEND UNDER SCAFFOLDING': 4,
#          'FAIL TO SIGN AND CERT OPEN ENTRIES': 1,
#          '393.33': 1,
#          'NO COMMERCIAL BIKE ID': 296,
#          'RECKLESS OPERATION OF BICYCLE': 332,
#          'CARRYING ARTICLES': 10,
#          'DROP AXLE OUT TIRE DEFECTIVE': 2,
#          'COMM BIKE NO PLATE': 1,
#          'TRUCK SPLASH GUARD MISSING': 1,
#          'RECKLESS OPERATION OF BIKE': 203,
#          'NO VISUAL DISTRESS FLAG': 1,
#          'PROHIBITED ZONE PEDDLE W/IN': 1,
#          'IN THE PARK AFTER CLOSING': 5,
#          'LANYARD  NOT ATTACHED TO OPERATOR (NAV)': 1,
#          'RECKLESS BICYCLE': 2,
#          'FAILURE TO PRODUCE VALID TRIP SHEET': 1,
#          'DISPLAY OVER 5FT HIGH': 1,
#          'NO REFLECTIVE DEVICE (WHEELS)': 1,
#          'OBSTRUCTING PARK BENCH': 39,
#          'EXP. NYS HEAVY DUTY INSPECTION': 2,
#          'NO REV LIGHT': 1,
#          'FAILED TO MAKE REQUIRED ENTRIES (TRIP SHEET)': 1,
#          'FAIL TO CARRY ID': 31,
#          'FAIL TO PRODUCE COMM BIKE ID': 19,
#          'FAILED TO DISPLAY LICENSE': 4,
#          'DRIVING W/ SUSPENDED REGISTRATION': 1,
#          'FAIL TO PRODUCE DOCUMENTS': 2,
#          'SMOKING ON SCHOOL GROUNDS': 63,
#          'NO FIRM ID': 38,
#          'TRACTOR REAR PLATE ILLUMINATION': 1,
#          'REGISTRATION': 2,
#          'VEND OVER VENTILATION GRILL': 3,
#          'VENDING UNDER SCAFFOLDING': 4,
#          'HEAVY DUTY INSPECTION': 2,
#          'UNLICENSED FOOD VENDOR': 347,
#          'LOOSE U-BOLT D/S': 1,
#          '392.9': 2,
#          'NO COMMERCIAL BICYCLE ID': 9,
#          'RECKLESS OPERATION OF A BICYCLE': 50,
#          'INSIDE PARK AFTER CLOSING': 9,
#          'EXHAUST MISSING': 1,
#          'OPEN CONT  OF ALCOHOL': 8,
#          'CROP AXLE IN TIRE DEFECTIVE': 1,
#          'NO TRAILER INSPECTION': 2,
#          'FAIL TO ISSUE ID WHILE MAKING DELIVERIES': 1,
#          'FAIL TO PRODUCE COM BIKE ID': 2,
#          'FAIL TO MAKE REQUIRED ENTRIES': 3,
#          'VENDING WITHIN 20 FT OF AN ENTRANCE': 1,
#          'FAILED TO WEAR VENDORS LICENSE WHILE WORKIN': 1,
#          'NO COMM BIKE ID': 104,
#          'NO COMMERCIA;L BIKE ID': 1,
#          'RECKLESS OPERATION BICYCLE': 26,
#          'IMPROPER STAND DISPLAY': 3,
#          'AXLE #2 OUT TIRE DEFECTIVE': 1,
#          'FAIL TO PRODUCE FIRM ID': 5,
#          'VENDING WITHIN 10FT OF CROSSWALK': 1,
#          'FIRE HYDRANT NEAR GENERAL VEND.': 1,
#          'SUSPENDED HVT': 1,
#          'NO VALID TRAILER INSURANCE': 1,
#          'RIDING BICYCLE WHILE LISTENING TO AUDIO DEVICE': 1,
#          'NO COMMERCIAL BIKE PLATE': 15,
#          'RECKLES  OPERATION OF BICYCLE': 1,
#          'NO DISTRESS FLAG': 12,
#          'DEF WINSHIELD': 2,
#          'RECKLESS OPERATION OF A BIKE': 80,
#          '393.75': 4,
#          'NO LANYARD ATTACHED TO OPERATOR': 1,
#          'NO TLC LICENSE': 24,
#          'RCNY': 1,
#          'VENDING WITHIN 20 FT FROM BUSINESS': 1,
#          'NO 10 BC EXT': 1,
#          'DEF INT LIT': 1,
#          'NO BATT CVER': 22,
#          'NO BATT COVER': 14,
#          'UNLICENSED HACK': 4,
#          'DEF. P/S DIRECTIONAL': 1,
#          'PRESENT IN PARK W/O CHILD': 1,
#          'NO TRIANGLES': 78,
#          'ADULT IN PLAYGROUND NO CHILD': 11,
#          'NO PLATES': 1,
#          'OPER. VEH WHILE REG SUSP.': 1,
#          'NO BRAKE LT': 1,
#          'DEF BRAKES': 2,
#          'FAIL TO MAKE REQUIRED TRIP SHEET ENTRIES': 1,
#          'LICENSE NOT CONSPICOUSLY POSTED': 1,
#          'NO BATTERY COVER ON VEH.': 1,
#          'IN PLAYGROUND W/O CHILD': 62,
#          'NO FIRE EXTG': 40,
#          'ILLEGAL ADVERTISE': 1,
#          'OBSTRUCTING FRONT ENTRANCE': 172,
#          'NO IFTA STICKER': 101,
#          'FAIL TO DISPLAY PRICES': 45,
#          'DEF. F/D/S BOX CLEARING LGT.': 1,
#          'NO MVT STKR': 2,
#          'OBSTR. BRAKE LTS.': 1,
#          'NO TAGS ON COLLARED DOG': 1,
#          'NO ADDRESS ON VECH': 2,
#          'DEF. HEADLIGHTS': 1,
#          'FOOD ON FLR': 1,
#          'POSSESES MARKER FOR GRAFFITTI': 1,
#          'FAILED TO DISPLAY PRICE': 10,
#          "NO U.S. DOT #'S": 4,
#          'FOOD/FLOOR': 3,
#          'DEF HORN': 17,
#          'NO HORN': 18,
#          'DEF. EMERGENCY BRAKE': 1,
#          'OPEN CONTAINER IN PUBLIC': 22,
#          'BRKN LF/SPRNG': 1,
#          'FAILURE TO EXHIBIT LIC': 2,
#          'DEF WIPER': 4,
#          'UNSEC LOAD': 23,
#          'OPERATOR NOT LIC BY TLC': 30,
#          'DEF BRAKE LTS': 7,
#          'LOW TIRE PRESS': 1,
#          'NO FIRE EXT.': 8,
#          'OPERATING A TORCH WITHOUT CERTIFICATE OF FITNESS': 1,
#          'PIC KUP BUS': 1,
#          'NO INT LTS': 1,
#          'NO SAFETY TRIANGLES': 15,
#          'NO DOT#S': 18,
#          'D/S BRAKE HOSE CUT TO CORDS': 1,
#          'SMOKING IN ENCLOSED AREA': 34,
#          'NO DAILY INSP': 31,
#          'FOOD ON FLOOR': 4,
#          'DEF TIR ROD': 1,
#          'DEF CLER LT': 1,
#          'PRODUCE ON FLOOR': 1,
#          'PW/*STEER LKING': 1,
#          'DISCON THREATING BEHAVIOR': 1,
#          'LOOSE U/B/O IT': 1,
#          'IMPROPER STAND': 14,
#          'BRAKE PADS LESS 1/4': 1,
#          'DEF P/S REV LT': 2,
#          'NO DOOR MARKINGS D/S': 1,
#          'DEF P/S REV CL LTS': 1,
#          'UNLIIC FOOD VENDOR': 1,
#          'P/S WIPER BLADE BROKEN': 1,
#          'ILLEGAL USE OF OPEN FLAME (TORCH)': 1,
#          'FAIL TO MAINTAIN VEH.': 2,
#          'P/U IN BUS STOP': 60,
#          'MISSING RIP ENTRIES': 1,
#          'GREASE CAP LKING': 1,
#          'DEF R/ID LT': 2,
#          'BLOCKING FRONT ENTRANCE': 135,
#          'DEF TIRE': 10,
#          'NO MVT STICKER': 15,
#          'OPNE CONT OF ALCOHOL': 7,
#          'DEF. CITY HORN': 1,
#          'FAIL TO CARRY LICENSE ON DEMAND': 3,
#          'PEDDLER RESTRICTED LOCATION': 2,
#          'MISS WIPER': 1,
#          '3RD AXLE OUTSIDE TIRE FLAT P/S': 1,
#          'NO SPLAH GRDS': 1,
#          'NO ANN INSP': 4,
#          'EXHST LEAK': 4,
#          'L/S DRAG LNK LOOSE': 1,
#          'NO SAF TRANGLES': 1,
#          'MISS LUGNUT': 1,
#          'SHIFTED LEAF SPRING': 1,
#          'NO CAPACITY FULL SIGN POSTED': 10,
#          'OPERATE BICYCLE ON SIDEWALK': 10,
#          'UNAUTH USE OF CELL PHONE WHILE DRIVING 1225 C (2) A': 1,
#          'VENDING 20 FT FROM A BUSINESS': 1,
#          'OBSTRUCT BUS STOP': 8,
#          'DEF. INTERIOR CAB LGT.': 1,
#          'EXPOSER OF A PERSON': 1,
#          'NO TAX ID': 10,
#          'NO ENGLISH': 5,
#          'FAILED TO CARRY/PRODUCE LICENSE ON DEMAND': 2,
#          'FAIL TO DISPLAY CERTIFICATE': 3,
#          'LOOSE U-BOLT D/S REAR': 1,
#          'DISPLAY MORE THAN 8FT LONG': 1,
#          'VEND NEAR HYDRANT': 1,
#          'NO SA F TRI': 1,
#          'DEF BRAKE LT': 3,
#          'DEF EXHST PIPE': 2,
#          'RECKLESS OEPRATION OF BICYCLE': 7,
#          'MISS REFLECTOR': 1,
#          'CRACK W/SHIELD': 3,
#          'NO SAF TRI': 11,
#          'POWER STEERING LEAK AT PUMP': 2,
#          'VENDING FROM PARKED MOTOR VEHICLE': 2,
#          'VENDING WITHIN 20 FT OF A BUILDING ENTRANCE': 2,
#          'OPEN CONTAINER OF ALCOHOL': 172,
#          "NOT AT CURB / VEND ON SIDEWALK 12' WIDE": 1,
#          'HOLES IN REAR CARGO FOOD': 1,
#          'FAILURE TO PROVIDE A FIRE GUARD DURING OPERATION OF TORCH': 1,
#          'FAILURE TO DISPLAY PRICE': 11,
#          'DEF MARKER L;T': 1,
#          'IMPROPER DISPLAY STAND': 2,
#          'INADEQUATELY ATTENDED LOT': 15,
#          'REFG NOT WORKIN': 1,
#          '2 AXLE R/S BRAKE DRUM CONT. W/ OIL': 1,
#          'RECKLESS OPERATION': 30,
#          'RECKLESS OPERATION SKATEBOARD PUBLIC X-WALK': 1,
#          'INTERFERING WITH MTA OPERATIONS': 16,
#          'CROSSBEAM FRAME LF CRACKED': 1,
#          'EXP MED CARD': 4,
#          'DEF SPRING BRKE': 1,
#          'DEF TRN SIGNAL': 1,
#          'AXLE 2 IN TIRE DEFECTIVE': 1,
#          'NO REV LTS': 17,
#          'VENDING 20 FEET FROM BLDG': 1,
#          'NO CITY HORN': 11,
#          'FAIR IN  BUS STOP': 1,
#          'L/R DEF TAIL LT': 1,
#          'NO MANIFEST': 2,
#          'VEHICLE NOT LIC BY TLC': 10,
#          'FAILED TO EXHIBIT LICENSE ON DEMAND': 3,
#          'NO COMM ID': 7,
#          'NO ADDRESS ON VEH.': 2,
#          'UNAUTH RADIO': 28,
#          'NO COMM FIRM ID': 4,
#          'SMOKING CIGARETTE IN LOBBY': 1,
#          'HEADLGT. DEF. P/S': 1,
#          'NO LOW AIR WARNING DEVICE': 1,
#          'VENDOR SELLING WITHIN TAXI STAND': 1,
#          'LOW AIR PRESS': 2,
#          'FAILED TO DISPLAY/PRODUCE VENDORS LICENSE': 1,
#          "WITHIN 5' FROM PHONE BOOTH": 1,
#          'HANDLING FOOD W/BARE CONTACT': 1,
#          'DEF D/S WINDOW CRANK': 1,
#          'LOOSE FUEL TANK STRAP 1 OF 2': 1,
#          'TORN SCRAPING': 1,
#          'NO NYS EMMISSION INSPECTION': 2,
#          'OOPEN CONT OF ALCOHOL': 1,
#          'NO TURN SIGNAL': 1,
#          'NO FIRE EXTINGUISHER': 295,
#          'MDW': 1,
#          'MISS STEP': 2,
#          'OPER. NOT LIC. BY TLC': 17,
#          'EXHAUST LEAK - BY MUFFLER STRAPS': 1,
#          'CONSUMPTION AFTER HOURS': 2,
#          "PICK UP MORE THAN 12'' FROM CURB": 1,
#          'VISIBLE AIR POLLUTANTFROM VEHICLE': 1,
#          'NO R/PLTE LT': 3,
#          'CRCKED BRKE HOSE': 1,
#          'FAIL TO FILL OUT TRIP SHEET': 1,
#          'DEF TAIL LT': 6,
#          'FOOD NOT REFG': 3,
#          'NO VALID IDENTIFICATION IN NYC': 1,
#          'NO PERMIT FOR PUSH CART': 17,
#          'DEF. LGTS.': 1,
#          'NO FIRE DEPT PERMIT AIR COMP.': 1,
#          'IN PARK AFTER DARK': 108,
#          'IMPROPER DISPLAY TAX STANP': 1,
#          'NO HEAD LIGHT': 1,
#          'TIRE CUT': 1,
#          'SUSP. REG': 11,
#          'DRIVER SIDE MIRROR BROKEN': 1,
#          'CROSS IN FRONT OF MOVING VEHICLE': 1,
#          'UNSAFE OPERATION': 11,
#          'FAILED TO WEAR VENDORS LICENSE WHILE WORKING': 1,
#          'ERASURE ON TRIP SHEET': 1,
#          'STRIP/DISMANTLE VEH.': 1,
#          'SUSPENDED NYS REG/PLATES': 1,
#          'GREASE CAP LKING RT/FT': 1,
#          'T.O.S 1085SUB 9': 1,
#          'NO BRAKE LTS': 3,
#          'DEF D/ SEAT': 1,
#          'CUT SIDEWALL 3 AXLE': 1,
#          'OPEN CONT OF ALCOHOL IN PUBLIC': 129,
#          'DEF DIRECTIONAL': 1,
#          'RESTRICTED AREA PEDDLE IN': 1,
#          'DEF REV LTS': 13,
#          'VENDING WITHIN 10 FT OF CROSSWALK': 4,
#          'DEF LIC PLTE LT': 4,
#          'F/L HUB LEAKING': 1,
#          'CRUISING SOLICITING PROHIB': 1,
#          'VENDING AWAY FROM CURB': 1,
#          'HANDS OFF HANDLEBARS': 4,
#          'FAIL TO PRODUCE TRACTOR INSURANCE': 1,
#          'SLACK ADJUSTER OUT OF ADJUSTMENT': 1,
#          ...})

# %%
# Print the most frequent values in column 'PD_DESC'

profiles.column('SUMMONS_CATEGORY_TYPE').get('topValues')
# Out:
# [('ALCOHOL', 1418360),
#  ('DISORDERLY CONDUCT', 817343),
#  ('PARK REGS', 310657),
#  ('URINATING', 294578),
#  ('VTL', 258055),
#  ('BIKE', 254775),
#  ('NYS TRANS', 227766),
#  ('TLC', 220529),
#  ('OTHER ADMIN CODE', 214518),
#  ('MARIJUANA', 190431)]

# %%
ds_full.distinct('SUMMONS_CATEGORY_TYPE')
# Out:
# Counter({'VTL': 258055,
#          '': 97655,
#          'OTHER ABC': 34071,
#          'MARIJUANA': 190431,
#          'DISORDERLY CONDUCT': 817343,
#          'TRESPASS': 157997,
#          'ABC': 62956,
#          'TLC': 220529,
#          'TRAFFIC REGS': 12700,
#          'SPITTING': 24760,
#          'DOG': 52331,
#          'LITTERNG': 28303,
#          'KNIFE': 35496,
#          'BIKE': 254775,
#          'NYS TRANS': 227766,
#          'ALCOHOL': 1418360,
#          'PARK REGS': 310657,
#          'OTHER ADMIN CODE': 214518,
#          'FIREWORKS': 9482,
#          'VENDING': 166964,
#          'EXPOSURE': 9692,
#          'KEY': 20725,
#          'OPEN FIRE': 2826,
#          'OTHER PENAL LAW': 13125,
#          'NOISE': 133429,
#          'AIR GUN': 1555,
#          'LITTERING': 65832,
#          'BUSINESS': 6733,
#          'PANHANDLING': 6515,
#          'URINATING': 294578,
#          'HARASSMENT 2': 4658,
#          'TOW TRUCK': 3044,
#          'GAMBLING': 16154,
#          'OTHER PARK REG': 31109,
#          'POSTING ADVERTISEMENTS': 4603,
#          'SANITARY CODE': 792,
#          'IN PUBLIC UNDER DRUGS': 213,
#          'LOITERING': 6087,
#          'SMOKING': 14369,
#          'OPEN HYDRANT': 766,
#          'FOOD': 1107,
#          'DUMPING': 734,
#          'OTHER': 8644,
#          'AMMO': 167,
#          'AVIGATION': 36,
#          'OTHER TLC': 6582,
#          'SCALPING': 5261,
#          'OTHER HEALTH CODE': 16857,
#          'OTHER TRAFFIC REG': 16215,
#          'OTHER TAX LAW': 5153,
#          'TRANSIT REGS': 6624,
#          'MACE': 1282,
#          'OTHER ACA': 70,
#          'GRAFFITI': 558,
#          'OTHER TRANSIT REG': 3165,
#          'OTHER MULTIPLE DWELLING': 1104,
#          'EDUCATION LAW': 2022,
#          'OTHER GENERAL BUSINESS LAW': 4399,
#          'Other': 9711,
#          'OTHER VTL': 2287,
#          'NAVIGATION LAW': 5385,
#          'OTHER SANITARY CODE': 445,
#          'OTHER AGRICULTURE&MARKETS LAW': 370,
#          'OTHER NYS WORK COMP': 118,
#          'HAZING 2': 17,
#          'OTHER ENVIRON CONSERVATION LAW': 309,
#          'OTHER EDUCATION LAW': 44,
#          'OTHER BUSINESS LAW': 1654,
#          'ADMIN UNCLASS': 3714,
#          'UNAUTH. RADIO': 10,
#          'PROSTITUION': 133,
#          'OBSTRUCTED VIEW OF PREMIS': 1,
#          'NOISE (ENGIN EXHUST)': 24,
#          'NOISE (ANIMIAL)': 20,
#          'DISCON: OBSTRUCT PEDESTRI': 3,
#          'NO TRIP SHEET': 27,
#          'IDLING OF VEHICLE': 14,
#          'LEAVING THE SCENE OF AN A': 2,
#          'AGG. UNLICENSED OPER.': 4,
#          'NOISE (DEVICE)': 11,
#          'URINATE IN PARK': 1,
#          'NOISE (HORN/ALARM)': 6,
#          'URINATING IN PUBLIC': 4,
#          'VIOLATE LEARNERS PERMIT': 1,
#          'NO BUSINESS CERTIFICATE': 1,
#          'NO PREGNANCY WARNING SIGN': 1,
#          'Park Regs': 1,
#          'DOG IN PARK': 1,
#          'MISSING EQUIPMENT': 1,
#          'OFFENSIVE EXHIBITION': 2,
#          'UNLAWFUL PREVENTION OF PU': 1,
#          'IMPROPER STICKER': 1,
#          'REVOLKED REGISTRATION': 4,
#          'LOITERING FOR GAMBLING': 1,
#          'PROMOTING EXPOSURE': 1})

# %%
ds_full.distinct('LAW_DESCRIPTION')
# Out:
# Counter({'VTL': 256122,
#          'UNKNOWN': 92140,
#          'ABC': 97002,
#          'Penal Law': 1224278,
#          'Tax Law': 26632,
#          'Administrative Code': 2648518,
#          'Traffic Regs': 29206,
#          'Health Code': 289392,
#          'Park Regs': 369987,
#          'NYS Transportation': 227276,
#          'General Business Law': 16850,
#          'NYS Workers Comp': 445,
#          'Sanitary Code (NYS)': 1239,
#          'TLC': 7129,
#          'ACA': 5325,
#          'Transit Regs': 11715,
#          'Multiple Dwelling': 1106,
#          'Education Law (NYS)': 2066,
#          'Other': 22313,
#          'Navigation Law': 5386,
#          'Agriculture & Markets Law': 371,
#          'Environmental Conservation Law': 310,
#          'OTHER PARK REGS': 682,
#          'DOG: UNLICENSED': 427,
#          'BICYCLE NO BELL': 8,
#          'Health Laws': 223,
#          'ABC Laws': 99,
#          'Traffic Rules': 17})

# %%
def validate_law_cat_cd(sourceValue):
    UNKNOWN = "UNKNOWN"
    
    try:
        values = ["VTL", "ABC", "Penal Law","Tax Law",
         'Administrative Code',
         'Traffic Regs',
         'Health Code',
         'Park Regs',
         'NYS Transportation',
         'General Business Law',
         'NYS Workers Comp',
         'Sanitary Code (NYS)',
         'TLC',
         'ACA',
         'Transit Regs',
         'Multiple Dwelling',
         'Education Law (NYS)',
         'Other',
         'Navigation Law',
         'Agriculture & Markets Law',
         'Environmental Conservation Law',
         'OTHER PARK REGS',
         'DOG: UNLICENSED',
         'BICYCLE NO BELL',
         'Health Laws',
         'ABC Laws',
         'Traffic Rules'] 
        
        if sourceValue in values:
            return sourceValue
        else:
            return UNKNOWN
    except:
        return UNKNOWN

    
ds_full = ds_full.update('LAW_DESCRIPTION', validate_law_cat_cd)

# %%
ds_full.distinct('BORO')
# Out:
# Counter({'NEW YORK': 51983,
#          'BROOKLYN': 1414313,
#          'QUEENS': 879927,
#          'BRONX': 1047302,
#          'STATEN ISLAND': 146364,
#          '': 564609,
#          'MANHATTAN': 1231766})

# %%
def validate_boro_nm(sourceValue):
    UNKNOWN = "UNKNOWN"
    
    try:
        values = ["BRONX","BROOKLYN","MANHATTAN","QUEENS","STATEN ISLAND","NEW YORK"]
        
        if sourceValue in values:
            return sourceValue
        else:
            return UNKNOWN
    except:
        return UNKNOWN

    
ds_full = ds_full.update('BORO', validate_boro_nm)

# %%
profiles.column('JURISDICTION_CODE').get('topValues')
# Out:
# [('0', 4753370), ('2', 516972), ('1', 65922)]

# %%
ds_full.distinct('JURISDICTION_CODE')
# Out:
# Counter({'0': 4753370, '2': 516972, '1': 65922})

# %%
profiles.minmax('X_COORDINATE_CD')
# Out:
#         min      max
# int  913367  1067226

# %%
profiles.minmax('Y_COORDINATE_CD')
# Out:
#         min     max
# int  121131  272932

# %%
profiles.column('AGE_GROUP').get('topValues')
# Out:
# [('25-44', 2422557),
#  ('18-24', 1318103),
#  ('45-64', 1110025),
#  ('<18', 218912),
#  ('UNKNOWN', 109312),
#  ('65+', 72618),
#  ('819', 21),
#  ('818', 19),
#  ('933', 17),
#  ('822', 17)]

# %%
ds_full.distinct('AGE_GROUP')
# Out:
# Counter({'UNKNOWN': 194049,
#          '25-44': 2422557,
#          '45-64': 1110025,
#          '18-24': 1318103,
#          '<18': 218912,
#          '65+': 72618})

# %%
def validate_age_group(sourceValue):
    UNKNOWN = "UNKNOWN"
    
    try:
        values = ["25-44", "18-24", "45-64", "<18", "65+","UNKNOWN"]
        
        if sourceValue in values:
            return sourceValue
        else:
            return UNKNOWN
    except:
        return UNKNOWN

    
ds_full = ds_full.update('AGE_GROUP', validate_age_group)

# %%
profiles.column('RACE').get('topValues')
# Out:
# [('UNKNOWN', 4542966),
#  ('BLACK', 179554),
#  ('WHITE HISPANIC', 101554),
#  ('WHITE', 52804),
#  ('BLACK HISPANIC', 33313),
#  ('ASIAN / PACIFIC ISLANDER', 23993),
#  ('AMERICAN INDIAN/ALASKAN NATIVE', 2446),
#  ('OTHER', 1948),
#  ('HISPANIC', 1031)]

# %%
ds_full.distinct('RACE')
# Out:
# Counter({'UNKNOWN': 4940652,
#          'WHITE HISPANIC': 101554,
#          'BLACK': 179554,
#          'WHITE': 52804,
#          'OTHER': 1948,
#          'BLACK HISPANIC': 33313,
#          'ASIAN / PACIFIC ISLANDER': 23993,
#          'AMERICAN INDIAN/ALASKAN NATIVE': 2446})

# %%
def validate_race(sourceValue):
    UNKNOWN = "UNKNOWN"
    
    try:
        values = ["UNKNOWN", "WHITE HISPANIC", "BLACK", "BLACK HISPANIC", "WHITE", "ASIAN / PACIFIC ISLANDER","AMERICAN INDIAN/ALASKAN NATIVE", "OTHER"]
        
        if sourceValue in values:
            return sourceValue
        else:
            return UNKNOWN
    except:
        return UNKNOWN

    
ds_full = ds_full.update('RACE', validate_race)

# %%
profiles.column('SEX').get('topValues')
# Out:
# [('M', 4472662), ('F', 611055), ('D', 110248), ('U', 65485)]

# %%
ds_full.distinct('SEX')
# Out:
# Counter({'U': 142299, 'M': 4472662, 'F': 611055, 'D': 110248})

# %%
def validate_sex(sourceValue):
    UNKNOWN = "U"
    
    try:
        values = ["M", "F", "U","D"] 
        
        if sourceValue in values:
            return sourceValue
        else:
            return UNKNOWN
    except:
        return UNKNOWN

    
ds_full = ds_full.update('SEX', validate_sex)

# %%
profiles.minmax('Latitude')
# Out:
#              min        max
# float  40.498905  40.915782

# %%
def validate_lat(sourceValue):
    UNKNOWN = -999
    
    try:
        if sourceValue >= 40 and sourceValue <= 41:  
            return sourceValue
        else:
            return UNKNOWN
    except:
        return UNKNOWN

    
ds_full = ds_full.update('Latitude', validate_lat)

# %%
profiles.minmax('Longitude')
# Out:
#              min        max
# float -74.254903 -73.700577

# %%
def validate_long(sourceValue):
    UNKNOWN = -999
    
    try:
        if sourceValue >= -74 and sourceValue <= -73:  
            return sourceValue
        else:
            return UNKNOWN
    except:
        return UNKNOWN

    
ds_full = ds_full.update('Latitude', validate_long)

# %%
profiles.minmax('Lon_Lat')
# Out:
#                                               min  \
# str  POINT (-73.70057651099997 40.73903832800004)
#
#                                               max
# str  POINT (-74.25490278599993 40.50771206300004)

# %%
SELECTED_COLUMNS = [\
    'SUMMONS_KEY',\
    'SUMMONS_DATE',\
    'OFFENSE_DESCRIPTION',\
    'LAW_SECTION_NUMBER',\
    'LAW_DESCRIPTION',\
    'SUMMONS_CATEGORY_TYPE',\
    'AGE_GROUP',\
    'SEX',\
    'RACE',\
    'JURISDICTION_CODE',\
    'BORO',\
    'PRECINCT_OF_OCCUR',\
    'X_COORDINATE_CD',\
    'Y_COORDINATE_CD',\
    'Latitude',\
    'Longitude',\
    'Lon_Lat',\
]

ds_full = ds_full.select(SELECTED_COLUMNS)

# %%
ds_full

# %% [markdown]
# # VALIDATING DATA AFTER CLEANING

# %%
data_df = pd.read_csv("NYPD-Criminal-Court-Summons-Historic.csv")

# %%
data_df = data_df.dropna()

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4246146 entries, 4 to 5336262
# Data columns (total 17 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   SUMMONS_KEY            int64
#  1   SUMMONS_DATE           object
#  2   OFFENSE_DESCRIPTION    object
#  3   LAW_SECTION_NUMBER     object
#  4   LAW_DESCRIPTION        object
#  5   SUMMONS_CATEGORY_TYPE  object
#  6   AGE_GROUP              object
#  7   SEX                    object
#  8   RACE                   object
#  9   JURISDICTION_CODE      int64
#  10  BORO                   object
#  11  PRECINCT_OF_OCCUR      int64
#  12  X_COORDINATE_CD        float64
#  13  Y_COORDINATE_CD        float64
#  14  Latitude               float64
#  15  Longitude              float64
#  16  Lon_Lat                object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 583.1+ MB

# %%
ds_full_jc = stream(data_df)
profiles = ds_full_jc.profile(default_profiler=DefaultColumnProfiler)
profiles.stats()
# Out:
#                          total  empty  distinct    uniqueness    entropy
# SUMMONS_KEY            4246146      0   4246141  9.999988e-01  22.017720
# SUMMONS_DATE           4246146      0      5074  1.194966e-03  11.804854
# OFFENSE_DESCRIPTION    4246146      0       291  6.853274e-05   4.873426
# LAW_SECTION_NUMBER     4246146      0       248  5.840591e-05   4.702379
# LAW_DESCRIPTION        4246146      0        24  5.652184e-06   2.097447
# SUMMONS_CATEGORY_TYPE  4246146      0        66  1.554351e-05   3.803605
# AGE_GROUP              4246146      0       213  5.016314e-05   1.829645
# SEX                    4246146      0         4  9.420307e-07   0.622910
# RACE                   4246146      0         8  1.884061e-06   0.531446
# JURISDICTION_CODE      4246146      0         3  7.065230e-07   0.588972
# BORO                   4246146      0         6  1.413046e-06   2.136169
# PRECINCT_OF_OCCUR      4246146      0        78  1.836960e-05   6.054245
# X_COORDINATE_CD        4246146      0     54765  1.289758e-02  13.736021
# Y_COORDINATE_CD        4246146      0     58123  1.368841e-02  13.863700
# Latitude               4246146      0    100772  2.373258e-02  14.211423
# Longitude              4246146      0    101156  2.382302e-02  14.212416
# Lon_Lat                4246146      0    105918  2.494450e-02  14.230700

# %%
data_df.to_csv('filtered4.csv')
