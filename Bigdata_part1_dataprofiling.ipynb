# %%
import sys #access to system parameters https://docs.python.org/3/library/sys.html
print("Python version: {}". format(sys.version))

import pandas as pd #collection of functions for data processing and analysis modeled after R dataframes with SQL like features
print("pandas version: {}". format(pd.__version__))

import matplotlib #collection of functions for scientific and publication-ready visualization
import matplotlib as plt
print("matplotlib version: {}". format(matplotlib.__version__))

import numpy as np #foundational package for scientific computing
print("NumPy version: {}". format(np.__version__))

import scipy as sp #collection of functions for scientific computing and advance mathematics
print("SciPy version: {}". format(sp.__version__)) 

import IPython
from IPython import display #pretty printing of dataframes in Jupyter notebook
print("IPython version: {}". format(IPython.__version__)) 



import sklearn #collection of machine learning algorithms
print("scikit-learn version: {}". format(sklearn.__version__))

#misc libraries
import random
import time
#ignore warnings
import warnings
warnings.filterwarnings('ignore')
print('-'*25)
import re
import os
from openclean.pipeline import stream
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Python version: 3.9.7 (v3.9.7:1016ef3790, Aug 30 2021, 16:39:15)
# [Clang 6.0 (clang-600.0.57)]
# pandas version: 1.3.4
# matplotlib version: 3.4.3
# NumPy version: 1.21.3
# SciPy version: 1.7.1
# IPython version: 7.29.0
# scikit-learn version: 1.0.1
# -------------------------

# %%
url = 'https://data.cityofnewyork.us/api/views/qgea-i56i/rows.csv?accessType=DOWNLOAD'

# %%
ds = stream(os.path.join('/Users/sakethreddypuchala/Downloads', 'NYPD_Complaint_Data_Historic.csv'))

# %%
ds.head(20)
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM ADDR_PCT_CD  \
# 0   394506329   12/31/2019     17:30:00                                    32
# 1   968873685   12/29/2019     16:31:00   12/29/2019     16:54:00          47
# 2   509837549   12/15/2019     18:45:00                                   109
# 3   352454313   12/28/2019     01:00:00                                    47
# 4   248803469   09/05/2008     21:41:00
# 5   293718737   12/27/2019     22:00:00                                     9
# 6   552685226   12/27/2019     20:10:00   12/27/2019     20:15:00          79
# 7   134037758   12/26/2019     20:00:00   12/27/2019     07:15:00         101
# 8   855385879   12/26/2019     19:57:00                                    44
# 9   241602326   12/25/2019     23:00:00   12/26/2019     14:25:00          20
# 10  585574881   12/24/2019     16:00:00                                    14
# ...

# %% [markdown]
# Data types and data has been loaded and reviewed

# %%
ds.columns
# Out:
# ['CMPLNT_NUM',
#  'CMPLNT_FR_DT',
#  'CMPLNT_FR_TM',
#  'CMPLNT_TO_DT',
#  'CMPLNT_TO_TM',
#  'ADDR_PCT_CD',
#  'RPT_DT',
#  'KY_CD',
#  'OFNS_DESC',
#  'PD_CD',
#  'PD_DESC',
#  'CRM_ATPT_CPTD_CD',
#  'LAW_CAT_CD',
#  'BORO_NM',
#  'LOC_OF_OCCUR_DESC',
#  'PREM_TYP_DESC',
#  'JURIS_DESC',
#  'JURISDICTION_CODE',
#  'PARKS_NM',
#  'HADEVELOPT',
#  'HOUSING_PSA',
#  'X_COORD_CD',
#  'Y_COORD_CD',
#  'SUSP_AGE_GROUP',
#  'SUSP_RACE',
#  'SUSP_SEX',
#  'TRANSIT_DISTRICT',
#  'Latitude',
#  'Longitude',
#  'Lat_Lon',
#  'PATROL_BORO',
#  'STATION_NAME',
#  'VIC_AGE_GROUP',
#  'VIC_RACE',
#  'VIC_SEX']

# %%
ds.count()
# Out:
# 7375993

# %%
profiles = ds.profile()
profiles
# Out:
# [{'column': 'CMPLNT_NUM',
#   'stats': {'totalValueCount': 7375993,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 7375993})}),
#    'minmaxValues': {'int': {'minimum': 100000065, 'maximum': 999999904}}}},
#  {'column': 'CMPLNT_FR_DT',
#   'stats': {'totalValueCount': 7375993,
#    'emptyValueCount': 655,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'date': 7375338})}),
#    'minmaxValues': {'date': {'minimum': datetime.datetime(1010, 5, 14, 0, 0),
#      'maximum': datetime.datetime(2020, 12, 31, 0, 0)}}}},
#  {'column': 'CMPLNT_FR_TM',
#   'stats': {'totalValueCount': 7375993,
#    'emptyValueCount': 48,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'date': 7375945})}),
#    'minmaxValues': {'date': {'minimum': datetime.datetime(2021, 11, 20, 0, 0),
#      'maximum': datetime.datetime(2021, 11, 20, 23, 59)}}}},
# ...

# %%
profiles.stats()['empty']
# Out:
# CMPLNT_NUM                 0
# CMPLNT_FR_DT             655
# CMPLNT_FR_TM              48
# CMPLNT_TO_DT         1704204
# CMPLNT_TO_TM         1699541
# ADDR_PCT_CD             2166
# RPT_DT                     0
# KY_CD                      0
# OFNS_DESC              18823
# PD_CD                   6278
# PD_DESC                 6278
# CRM_ATPT_CPTD_CD           7
# LAW_CAT_CD                 0
# BORO_NM                11329
# LOC_OF_OCCUR_DESC    1543800
# PREM_TYP_DESC          40745
# JURIS_DESC                 0
# JURISDICTION_CODE       6278
# PARKS_NM             3229345
# HADEVELOPT           7029181
# HOUSING_PSA          1241432
# X_COORD_CD             17339
# Y_COORD_CD             17339
# SUSP_AGE_GROUP       4795235
# SUSP_RACE            3426694
# SUSP_SEX             3560008
# TRANSIT_DISTRICT     7212494
# Latitude               17339
# Longitude              17339
# Lat_Lon                17339
# PATROL_BORO             6735
# STATION_NAME         7212494
# ...

# %%
## data type for each column
profiles.types()
# Out:
#                       date    float      int      str
# CMPLNT_NUM               0        0  7375993        0
# CMPLNT_FR_DT       7375338        0        0        0
# CMPLNT_FR_TM       7375945        0        0        0
# CMPLNT_TO_DT       5671789        0        0        0
# CMPLNT_TO_TM       5675076        0        0     1376
# ADDR_PCT_CD              0        0  7373827        0
# RPT_DT             7375993        0        0        0
# KY_CD                    0        0  7375993        0
# OFNS_DESC                0        0        0  7357170
# PD_CD                    0        0  7369715        0
# PD_DESC                  0        0        0  7369715
# CRM_ATPT_CPTD_CD         0        0        0  7375986
# LAW_CAT_CD               0        0        0  7375993
# BORO_NM                  0        0        0  7364664
# LOC_OF_OCCUR_DESC        0        0        0  5832193
# PREM_TYP_DESC            0        0        0  7335248
# ...

# %%
##Columns with multiple datatypes
profiles.multitype_columns().types()
# Out:
#                    date  float     int      str
# CMPLNT_TO_TM    5675076      0       0     1376
# HOUSING_PSA           0  33121  524464  5576976
# SUSP_AGE_GROUP        0      0     211  2580547
# VIC_AGE_GROUP         0      0     456  5737092

# %%
ds.distinct('CMPLNT_TO_TM')
# Out:
# Counter({'': 1699541,
#          '16:54:00': 1226,
#          '20:15:00': 16360,
#          '07:15:00': 8718,
#          '14:25:00': 7927,
#          '20:30:00': 37400,
#          '04:24:00': 693,
#          '01:44:00': 1039,
#          '00:12:00': 1464,
#          '20:24:00': 1341,
#          '11:22:00': 1013,
#          '08:00:00': 85709,
#          '17:15:00': 18108,
#          '02:10:00': 7580,
#          '23:00:00': 46215,
#          '01:39:00': 1025,
#          '22:20:00': 10953,
#          '06:27:00': 346,
#          '02:19:00': 826,
#          '02:12:00': 1045,
#          '15:40:00': 15939,
#          '15:15:00': 19845,
#          '11:30:00': 37226,
#          '11:00:00': 67433,
#          '12:30:00': 40262,
#          '11:15:00': 13205,
#          '03:40:00': 5905,
#          '17:30:00': 44553,
#          '21:00:00': 52869,
#          '00:00:00': 16879,
#          '15:00:00': 89393,
#          '21:15:00': 14862,
#          '09:00:00': 83191,
#          '20:40:00': 12900,
# ...

# %%
profiles.minmax('CMPLNT_FR_DT')
# Out:
#                       min        max
# date  1010-05-14 00:00:00 2020-12-31

# %%
profiles.minmax('CMPLNT_FR_TM')
# Out:
#             min                 max
# date 2021-11-20 2021-11-20 23:59:00

# %%
profiles.minmax('CMPLNT_TO_TM')
# Out:
#                       min                  max
# date  2021-11-20 00:00:00  2021-11-20 23:59:00
# str              24:00:00             24:00:00

# %%
profiles.minmax('HOUSING_PSA')
# Out:
#          min      max
# str    1,193       NA
# float  218.0  70679.0
# int        5    71750

# %%
profiles.minmax('SUSP_AGE_GROUP')
# Out:
#        min      max
# str  18-24  UNKNOWN
# int   -985     2020

# %%
ds.head(30)
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM ADDR_PCT_CD  \
# 0   394506329   12/31/2019     17:30:00                                    32
# 1   968873685   12/29/2019     16:31:00   12/29/2019     16:54:00          47
# 2   509837549   12/15/2019     18:45:00                                   109
# 3   352454313   12/28/2019     01:00:00                                    47
# 4   248803469   09/05/2008     21:41:00
# 5   293718737   12/27/2019     22:00:00                                     9
# 6   552685226   12/27/2019     20:10:00   12/27/2019     20:15:00          79
# 7   134037758   12/26/2019     20:00:00   12/27/2019     07:15:00         101
# 8   855385879   12/26/2019     19:57:00                                    44
# 9   241602326   12/25/2019     23:00:00   12/26/2019     14:25:00          20
# 10  585574881   12/24/2019     16:00:00                                    14
# ...

# %%
ds.distinct('BORO_NM')
# Out:
# Counter({'MANHATTAN': 1771637,
#          'BRONX': 1599801,
#          'QUEENS': 1463554,
#          '': 11329,
#          'BROOKLYN': 2186681,
#          'STATEN ISLAND': 342991})

# %%
ds.distinct('PD_CD')
# Out:
# Counter({'793': 56612,
#          '729': 60754,
#          '638': 613331,
#          '117': 27671,
#          '': 6278,
#          '223': 55288,
#          '521': 7853,
#          '321': 237811,
#          '639': 374673,
#          '433': 24843,
#          '301': 11742,
#          '109': 232452,
#          '114': 25907,
#          '339': 113412,
#          '263': 11456,
#          '333': 364252,
#          '153': 3107,
#          '175': 42771,
#          '349': 55147,
#          '441': 116902,
#          '101': 640218,
#          '177': 4554,
#          '387': 746,
#          '254': 259062,
#          '157': 14033,
#          '258': 140045,
#          '155': 2135,
#          '397': 114674,
#          '231': 7478,
#          '637': 332066,
#          '412': 18109,
#          '343': 46776,
#          '739': 73871,
#          '515': 6111,
#          '792': 15638,
#          '916': 69490,
#          '421': 73659,
#          '105': 26785,
#          '380': 2598,
#          '388': 21189,
# ...

# %%
ds.distinct('OFNS_DESC')
# Out:
# Counter({'DANGEROUS WEAPONS': 161447,
#          'FORGERY': 72712,
#          'HARRASSMENT 2': 945389,
#          'MISCELLANEOUS PENAL LAW': 185789,
#          'MURDER & NON-NEGL. MANSLAUGHTER': 6278,
#          'BURGLARY': 254292,
#          'DANGEROUS DRUGS': 427058,
#          'PETIT LARCENY': 1244155,
#          'OFF. AGNST PUB ORD SENSBLTY &': 383332,
#          'GRAND LARCENY': 638972,
#          'FELONY ASSAULT': 286085,
#          'ASSAULT 3 & RELATED OFFENSES': 774177,
#          'ARSON': 17658,
#          'RAPE': 21648,
#          'SEX CRIMES': 88030,
#          'GRAND LARCENY OF MOTOR VEHICLE': 133845,
#          'ROBBERY': 266447,
#          'CRIMINAL MISCHIEF & RELATED OF': 744951,
#          'THEFT-FRAUD': 76655,
#          'VEHICLE AND TRAFFIC LAWS': 91809,
#          'CRIMINAL TRESPASS': 82135,
#          'OFFENSES INVOLVING FRAUD': 23076,
#          'FRAUDS': 44473,
#          'OFFENSES AGAINST PUBLIC ADMINI': 137502,
#          'OFFENSES AGAINST THE PERSON': 18170,
# ...

# %%
profiles.column('ADDR_PCT_CD').get('topValues')

# %%
ds.distinct('CRM_ATPT_CPTD_CD')
# Out:
# Counter({'COMPLETED': 7250300, 'ATTEMPTED': 125686, '': 7})

# %%
ds.distinct('LAW_CAT_CD')
# Out:
# Counter({'FELONY': 2275064, 'VIOLATION': 960209, 'MISDEMEANOR': 4140720})

# %%
ds.distinct('JURIS_DESC')
# Out:
# Counter({'N.Y. POLICE DEPT': 6556968,
#          'METRO NORTH': 822,
#          'N.Y. HOUSING POLICE': 562181,
#          'N.Y. STATE POLICE': 1883,
#          'DEPT OF CORRECTIONS': 9638,
#          'OTHER': 24147,
#          'HEALTH & HOSP CORP': 3692,
#          'N.Y. TRANSIT POLICE': 163810,
#          'PORT AUTHORITY': 34258,
#          'U.S. PARK POLICE': 282,
#          'STATN IS RAPID TRANS': 439,
#          'NYC PARKS': 1125,
#          'TRI-BORO BRDG TUNNL': 5677,
#          'NEW YORK CITY SHERIFF OFFICE': 279,
#          'N.Y. STATE PARKS': 456,
#          'LONG ISLAND RAILRD': 548,
#          'NYS DEPT TAX AND FINANCE': 106,
#          'CONRAIL': 16,
#          'AMTRACK': 188,
#          'FIRE DEPT (FIRE MARSHAL)': 477,
#          'POLICE DEPT NYC': 8955,
#          'SEA GATE POLICE DEPT': 30,
#          'NYC DEPT ENVIRONMENTAL PROTECTION': 14,
#          'NYS DEPT ENVIRONMENTAL CONSERVATION': 1,
#          'DISTRICT ATTORNEY OFFICE': 1})

# %%
ds.distinct('BORO_NM')
# Out:
# Counter({'MANHATTAN': 1771637,
#          'BRONX': 1599801,
#          'QUEENS': 1463554,
#          '': 11329,
#          'BROOKLYN': 2186681,
#          'STATEN ISLAND': 342991})

# %%
ds.distinct('ADDR_PCT_CD')
# Out:
# Counter({'32': 99951,
#          '47': 138911,
#          '109': 121025,
#          '': 2166,
#          '9': 87010,
#          '79': 117595,
#          '101': 63399,
#          '44': 184214,
#          '20': 60860,
#          '14': 166925,
#          '25': 100291,
#          '108': 77119,
#          '46': 155839,
#          '42': 118552,
#          '52': 154649,
#          '66': 70194,
#          '50': 67947,
#          '7': 61567,
#          '43': 189629,
#          '104': 105281,
#          '75': 237049,
#          '10': 62329,
#          '100': 39284,
#          '18': 117489,
#          '48': 119861,
#          '17': 50747,
#          '28': 78856,
#          '45': 93493,
#          '78': 53667,
#          '30': 68711,
#          '107': 77133,
#          '105': 109599,
#          '83': 101202,
#          '40': 178413,
#          '120': 145011,
#          '60': 93305,
#          '106': 90199,
#          '23': 95791,
#          '61': 90606,
#          '41': 100443,
# ...

# %%
ds.distinct('LOC_OF_OCCUR_DESC')
# Out:
# Counter({'': 1543800,
#          'FRONT OF': 1727410,
#          'REAR OF': 157302,
#          'OUTSIDE': 3813,
#          'INSIDE': 3747880,
#          'OPPOSITE OF': 195788})

# %%
ds.distinct('PREM_TYP_DESC')
# Out:
# Counter({'STREET': 2352311,
#          '': 40745,
#          'RESIDENCE - APT. HOUSE': 1564899,
#          'DEPARTMENT STORE': 144809,
#          'OTHER': 199770,
#          'RESIDENCE-HOUSE': 725940,
#          'RESIDENCE - PUBLIC HOUSING': 553247,
#          'ABANDONED BUILDING': 2827,
#          'HOSPITAL': 35193,
#          'DRUG STORE': 70116,
#          'CEMETERY': 854,
#          'PUBLIC BUILDING': 43986,
#          'FOOD SUPERMARKET': 40053,
#          'COMMERCIAL BUILDING': 190978,
#          'GYM/FITNESS FACILITY': 22943,
#          'CHAIN STORE': 167139,
#          'BUS STOP': 6212,
#          'GROCERY/BODEGA': 94682,
#          'FAST FOOD': 36335,
#          'STORE UNCLASSIFIED': 31669,
#          'HOTEL/MOTEL': 33547,
#          'RESTAURANT/DINER': 85640,
#          'BANK': 30868,
#          'BRIDGE': 7743,
#          'SHOE': 5142,
#          'PARKING LOT/GARAGE (PUBLIC)': 40170,
#          'CHURCH': 12912,
#          'ATM': 6088,
#          'HIGHWAY/PARKWAY': 21915,
# ...

# %%
ds.distinct('PARKS_NM')
# Out:
# Counter({'': 3229345,
#          'NA': 4118985,
#          'GRAND ARMY PLAZA BROOKLYN': 11,
#          'SUNSET PARK': 226,
#          'HAPPY WARRIOR PLAYGROUND': 15,
#          'POE PARK': 33,
#          'BRYANT PARK': 299,
#          'HUDSON RIVER PARK': 144,
#          'CITY HALL PARK': 20,
#          'SARA D. ROOSEVELT PARK': 345,
#          'BELT PARKWAY/SHORE PARKWAY': 81,
#          'HIGHBRIDGE PARK MANHATTAN SIDE': 248,
#          'ASTORIA PARK': 115,
#          'QUEENSBRIDGE PARK': 21,
#          'KISSENA PARK': 77,
#          'FLUSHING MEADOWS CORONA PARK': 1315,
#          'MCCARREN PARK': 194,
#          'HOLCOMBE RUCKER PARK': 23,
#          'CONFERENCE HOUSE PARK': 18,
#          'MARCUS GARVEY PARK': 433,
#          'CENTRAL PARK': 1641,
#          'VAN CORTLANDT PARK': 258,
#          'HARLEM RIVER PARK': 159,
#          'CALLAHAN-KELLY PLAYGROUND': 30,
#          'RICHMAN (ECHO) PARK': 214,
#          'FORT TRYON PARK': 105,
#          'UNION SQUARE PARK': 534,
# ...

# %%
ds.distinct('HADEVELOPT')
# Out:
# Counter({'': 7029181,
#          'LA GUARDIA': 2715,
#          'BOSTON SECOR': 1694,
#          'WILLIAMSBURG': 3627,
#          'SACK WERN': 1323,
#          'HAMMEL': 1683,
#          'COOPER PARK': 2182,
#          'WOODSON': 334,
#          'ARMSTRONG I': 1818,
#          'WALD': 3074,
#          'RED HOOK EAST': 3124,
#          'REDFERN': 1927,
#          'CLAREMONT PARKWAY-FRANKLIN AVENUE': 258,
#          'RICHMOND TERRACE': 2178,
#          'BORINQUEN PLAZA I': 2056,
#          'ASTORIA': 2101,
#          'DOUGLASS': 4879,
#          'WEST FARMS ROAD REHAB': 316,
#          'CASTLE HILL': 7555,
#          'CARLETON MANOR': 551,
#          'BUSHWICK II (GROUPS A & C)': 771,
#          'WAGNER': 1987,
#          'TILDEN': 4035,
#          'ATLANTIC TERMINAL SITE 4B': 832,
#          'TOMPKINS': 4069,
#          'CARVER': 729,
#          'PARK ROCK REHAB': 458,
#          'HUGHES APARTMENTS': 2292,
#          'TODT HILL': 1196,
#          'BAISLEY PARK': 496,
# ...

# %%
ds.distinct('X_COORD_CD')
# Out:
# Counter({'999937': 133,
#          '1022508': 245,
#          '1034178': 118,
#          '1026412': 160,
#          '1001215': 254,
#          '989665': 470,
#          '1001545': 207,
#          '1054394': 23,
#          '1007027': 1112,
#          '987147': 1261,
#          '987220': 23054,
#          '1001150': 227,
#          '996424': 537,
#          '1009507': 814,
#          '1008690': 218,
#          '1014563': 142,
#          '989260': 105,
#          '1008839': 159,
#          '987063': 1451,
#          '1023380': 1082,
#          '1008798': 2474,
#          '1011048': 138,
#          '1013091': 455,
#          '984623': 2493,
#          '1036299': 381,
#          '988668': 165,
#          '1016804': 394,
#          '993626': 57,
#          '987545': 369,
#          '999342': 2138,
#          '1029992': 23,
#          '': 17339,
#          '1006434': 7324,
#          '998757': 24,
#          '999794': 1621,
#          '1015943': 141,
#          '1014932': 257,
# ...

# %%
ds.distinct('Latitude')
# Out:
# Counter({'40.82092679700002': 13,
#          '40.885701406000074': 30,
#          '40.74228115600005': 9,
#          '40.87531145100007': 41,
#          '40.698827283': 118,
#          '40.72075882100006': 105,
#          '40.695958362000056': 16,
#          '40.61157006600007': 6,
#          '40.84023413800003': 186,
#          '40.77287456000005': 14,
#          '40.75043076800005': 3558,
#          '40.80168405900002': 12,
#          '40.743124599000055': 276,
#          '40.85858397000004': 97,
#          '40.82227104100008': 103,
#          '40.86322306500005': 33,
#          '40.63254475200006': 8,
#          '40.87465879000007': 6,
#          '40.71195209300004': 268,
#          '40.823499964000064': 272,
#          '40.82256991600008': 426,
#          '40.69844340600008': 9,
#          '40.6725291': 185,
#          '40.74269929900004': 237,
#          '40.58740067900004': 105,
#          '40.76511454900003': 34,
#          '40.85752258300005': 39,
# ...

# %%
ds.distinct('Longitude')
# Out:
# Counter({'-73.94332421899996': 13,
#          '-73.86164032499995': 30,
#          '-73.81982408': 43,
#          '-73.84754521099995': 41,
#          '-73.938819047': 156,
#          '-73.98046642299995': 105,
#          '-73.93763162199998': 16,
#          '-73.74736517199995': 6,
#          '-73.91768411399994': 186,
#          '-73.98954212299998': 14,
#          '-73.98928217599996': 3558,
#          '-73.93895929199994': 12,
#          '-73.95606807299998': 276,
#          '-73.90869606999998': 97,
#          '-73.91169777999993': 103,
#          '-73.89041071099996': 33,
#          '-73.98195137599998': 8,
#          '-73.91108943699999': 6,
#          '-73.98985467599994': 268,
#          '-73.85861898699994': 272,
#          '-73.91130716899994': 426,
#          '-73.90335796299998': 9,
#          '-73.896030558': 185,
#          '-73.99865537999993': 237,
#          '-73.81260554099998': 105,
#          '-73.98405256399997': 34,
#          '-73.88231889499998': 39,
# ...

# %%
ds.distinct('Lat_Lon')
# Out:
# Counter({'(40.82092679700002, -73.94332421899996)': 9,
#          '(40.885701406000074, -73.86164032499995)': 22,
#          '(40.74228115600005, -73.81982408)': 2,
#          '(40.87531145100007, -73.84754521099995)': 25,
#          '(40.698827283, -73.938819047)': 138,
#          '(40.72075882100006, -73.98046642299995)': 62,
#          '(40.695958362000056, -73.93763162199998)': 11,
#          '(40.61157006600007, -73.74736517199995)': 5,
#          '(40.84023413800003, -73.91768411399994)': 127,
#          '(40.77287456000005, -73.98954212299998)': 5,
#          '(40.75043076800005, -73.98928217599996)': 2300,
#          '(40.80168405900002, -73.93895929199994)': 9,
#          '(40.743124599000055, -73.95606807299998)': 187,
#          '(40.85858397000004, -73.90869606999998)': 76,
#          '(40.82227104100008, -73.91169777999993)': 77,
#          '(40.86322306500005, -73.89041071099996)': 24,
#          '(40.63254475200006, -73.98195137599998)': 5,
# ...

# %%
ds.distinct('VIC_SEX')
# Out:
# Counter({'E': 1150943,
#          'F': 2887858,
#          'M': 2434792,
#          'D': 902088,
#          '': 308,
#          'U': 4})

# %%
ds.distinct('VIC_RACE')
# Out:
# Counter({'UNKNOWN': 2432937,
#          'WHITE HISPANIC': 1192045,
#          'BLACK': 1770611,
#          'BLACK HISPANIC': 251094,
#          'WHITE': 1268395,
#          'ASIAN / PACIFIC ISLANDER': 427143,
#          'AMERICAN INDIAN/ALASKAN NATIVE': 33428,
#          '': 309,
#          'OTHER': 31})

# %%
ds.distinct('VIC_AGE_GROUP')
# Out:
# Counter({'UNKNOWN': 686421,
#          '25-44': 2433923,
#          '18-24': 749451,
#          '45-64': 1268365,
#          '<18': 339270,
#          '65+': 259662,
#          '': 1638445,
#          '-56': 3,
#          '-954': 4,
#          '943': 4,
#          '-967': 4,
#          '1018': 1,
#          '929': 11,
#          '-948': 5,
#          '-961': 2,
#          '-952': 3,
#          '936': 11,
#          '-71': 1,
#          '-943': 4,
#          '956': 3,
#          '-50': 1,
#          '941': 3,
#          '1013': 1,
#          '-942': 2,
#          '-39': 2,
#          '-69': 1,
#          '-67': 2,
#          '937': 9,
#          '-946': 2,
#          '-974': 5,
#          '960': 4,
#          '951': 4,
#          '927': 7,
#          '-2': 8,
#          '938': 10,
#          '-934': 3,
#          '-978': 5,
#          '-970': 7,
#          '-975': 2,
#          '-48': 3,
#          '-980': 3,
#          '-72': 3,
#          '946': 8,
#          '-959': 2,
# ...

# %%
ds.distinct('STATION_NAME')
# Out:
# Counter({'': 7212494,
#          '170 STREET': 1109,
#          'HOWARD BEACH-JFK AIRPORT': 199,
#          '34 STREET': 889,
#          '23 STREET': 1443,
#          'GRANT AVENUE': 341,
#          '96 STREET': 1558,
#          'FAR ROCKAWAY-MOTT AVE.': 299,
#          '34 ST.-PENN STATION': 3852,
#          'JACKSON AVENUE': 375,
#          '71 AVE.-FOREST HILLS': 812,
#          '59 STREET': 1703,
#          '42 ST.-GRAND CENTRAL': 3134,
#          '34 ST.-HERALD SQ.': 1501,
#          '96TH STREET': 81,
#          '42 STREET': 643,
#          'PARSONS/ARCHER-JAMAICA CENTER': 1497,
#          '161 ST.-YANKEE STADIUM': 1640,
#          '149 ST.-GRAND CONCOURSE': 902,
#          '40 STREET': 114,
#          '36 STREET': 587,
#          'EAST BROADWAY': 840,
#          '14 STREET': 4523,
#          '8 ST.-NYU': 160,
#          'NEWKIRK AVENUE': 310,
#          'MAIN ST.-FLUSHING': 694,
#          'UTICA AVENUE': 811,
#          '47-50 STS./ROCKEFELLER CTR.': 540,
# ...

# %%
ds.distinct('PATROL_BORO')
# Out:
# Counter({'PATROL BORO MAN NORTH': 878987,
#          'PATROL BORO BRONX': 1600584,
#          'PATROL BORO QUEENS NORTH': 757148,
#          '': 6735,
#          'PATROL BORO MAN SOUTH': 891844,
#          'PATROL BORO BKLYN NORTH': 1092429,
#          'PATROL BORO QUEENS SOUTH': 709396,
#          'PATROL BORO BKLYN SOUTH': 1095758,
#          'PATROL BORO STATEN ISLAND': 343112})
